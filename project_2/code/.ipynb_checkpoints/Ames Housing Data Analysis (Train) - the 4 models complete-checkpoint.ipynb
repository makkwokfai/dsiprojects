# %% [markdown]
# # Ames Housing Data Analysis (Train) - 2nd Attempt

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Dataset contains information from the Ames Assessor’s Office used in computing assessed values for individual residential properties sold in Ames, IA from 2006 to 2010.
#
# Using this dataset, we build a regression model to predict the selling prices of houses. For each Id in the test set, i will predict the value of the Sale Price variable.

# %%
# Import the necessary libaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Set row display option
pd.set_option('display.max_rows' , 100)
# pd.set_option('display.max_columns' , 100)

# modeling imports
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV

# Adding the gridline in graph
sns.set_style('whitegrid')

# %% [markdown]
# # Load the Data

# %%
train = pd.read_csv('../dataset/train.csv')

# %%
# Look at the data
train.head(10)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   109  533352170           60        RL           NaN     13517   Pave
# 1   544  531379050           60        RL          43.0     11492   Pave
# 2   153  535304180           20        RL          68.0      7922   Pave
# 3   318  916386060           60        RL          73.0      9802   Pave
# 4   255  906425045           50        RL          82.0     14235   Pave
# 5   138  535126040           20        RL         137.0     16492   Pave
# 6  2827  908186070          180        RM          35.0      3675   Pave
# 7   145  535154050           20        RL           NaN     12160   Pave
# 8  1942  535353130           20        RL           NaN     15783   Pave
# 9  1956  535426130           60        RL          70.0     11606   Pave
#
#   Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC  Fence  \
# 0   NaN       IR1          Lvl  ...            0         0     NaN    NaN
# ...

# %%
# Look at the data
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
# Look at the data
train.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# ...

# %% [markdown]
# # Following Data Documentation

# %% [markdown]
# Following advice in the special note of the data documentation, we will remove any houses with more than 4000 square feet from the data set.

# %%
# Initial data size
train.shape
# Out:
# (2051, 81)

# %%
# Look into houses with area of more than 4000 square feet
train.loc[(train['Gr Liv Area'] > 4000)]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 960   1499  908154235           60        RL         313.0     63887   Pave
# 1885  2181  908154195           20        RL         128.0     39290   Pave
#
#      Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 960    NaN       IR3          Bnk  ...            0       480      Gd   NaN
# 1885   NaN       IR1          Bnk  ...            0         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 960           NaN        0       1    2008        New     160000
# 1885         Elev    17000      10    2007        New     183850
#
# [2 rows x 81 columns]

# %%
# Dropping houses with area of more than 4000 square feet
train.drop(index=train.loc[train['Gr Liv Area'] > 4000].index , inplace=True)

# %%
# New data size
train.shape
# Out:
# (2049, 81)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Check for Null Values.

# %%
# Check for Null Values
train.isnull().sum()
# Out:
# Id                    0
# PID                   0
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        330
# Lot Area              0
# Street                0
# Alley              1909
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            55
# Bsmt Cond            55
# Bsmt Exposure        58
# BsmtFin Type 1       55
# BsmtFin SF 1          1
# BsmtFin Type 2       56
# BsmtFin SF 2          1
# ...

# %% [markdown]
# Drop those columns with more than 1000 Null values. i.e.
# `Alley`, `Fireplace Qu`, `Pool QC`, `Fence` & `Misc Feature`

# %%
# Initial data size
train.shape
# Out:
# (2049, 81)

# %%
# Dropping the five columns 
train.drop(columns=['Alley' , 'Fireplace Qu' , 'Pool QC' , 'Fence' , 'Misc Feature'],axis=1,inplace=True)

# %%
# New data size
train.shape
# Out:
# (2049, 76)

# %% [markdown]
# Filling up those missing values, with less than 1000 null. Replace those missing values after checking it.

# %%
train.isnull().sum()
# Out:
# Id                   0
# PID                  0
# MS SubClass          0
# MS Zoning            0
# Lot Frontage       330
# Lot Area             0
# Street               0
# Lot Shape            0
# Land Contour         0
# Utilities            0
# Lot Config           0
# Land Slope           0
# Neighborhood         0
# Condition 1          0
# Condition 2          0
# Bldg Type            0
# House Style          0
# Overall Qual         0
# Overall Cond         0
# Year Built           0
# Year Remod/Add       0
# Roof Style           0
# Roof Matl            0
# Exterior 1st         0
# Exterior 2nd         0
# Mas Vnr Type        22
# Mas Vnr Area        22
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Heating              0
# ...

# %% [markdown]
# Handling of `Lot Frontage` null data.

# %%
# Check the number of elements inside 'Lot Frontage'
train['Lot Frontage'].value_counts(dropna=False)
# Out:
# NaN      330
# 60.0     179
# 70.0      96
# 80.0      94
# 50.0      90
#         ...
# 111.0      1
# 155.0      1
# 119.0      1
# 153.0      1
# 135.0      1
# Name: Lot Frontage, Length: 119, dtype: int64

# %%
# Replace the missing values with the maximum occurance.
train['Lot Frontage'] = train['Lot Frontage'].fillna(train['Lot Frontage'].mode()[0])
train['Lot Frontage'].value_counts(dropna=False)
# Out:
# 60.0     509
# 70.0      96
# 80.0      94
# 50.0      90
# 65.0      71
#         ...
# 22.0       1
# 155.0      1
# 153.0      1
# 313.0      1
# 135.0      1
# Name: Lot Frontage, Length: 118, dtype: int64

# %% [markdown]
# Handling of `Mas Vnr Type` null data.

# %%
# Check the number of elements inside 'Mas Vnr Type'
train['Mas Vnr Type'].value_counts(dropna=False)
# Out:
# None       1218
# BrkFace     630
# Stone       166
# NaN          22
# BrkCmn       13
# Name: Mas Vnr Type, dtype: int64

# %%
# Replace the missing values with None (Most likely the house has no masonry veneer)
train['Mas Vnr Type'] = train['Mas Vnr Type'].fillna('None')
train['Mas Vnr Type'].value_counts(dropna=False)
# Out:
# None       1240
# BrkFace     630
# Stone       166
# BrkCmn       13
# Name: Mas Vnr Type, dtype: int64

# %% [markdown]
# Handling of `Mas Vnr Area` null data.

# %%
# Check the number of elements inside 'Mas Vnr Area'
train['Mas Vnr Area'].value_counts(dropna=False)
# Out:
# 0.0       1216
# NaN         22
# 120.0       11
# 200.0       10
# 176.0       10
#           ...
# 362.0        1
# 199.0        1
# 418.0        1
# 604.0        1
# 1095.0       1
# Name: Mas Vnr Area, Length: 372, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no masonry veneer)
train['Mas Vnr Area'] = train['Mas Vnr Area'].fillna(train['Mas Vnr Area'].mode()[0])
train['Mas Vnr Area'].value_counts(dropna=False)
# Out:
# 0.0      1238
# 120.0      11
# 176.0      10
# 200.0      10
# 72.0        9
#          ...
# 430.0       1
# 428.0       1
# 57.0        1
# 572.0       1
# 161.0       1
# Name: Mas Vnr Area, Length: 371, dtype: int64

# %% [markdown]
# Handling of `Bsmt Qual` null data.

# %%
# Check the number of elements inside 'Bsmt Qual'
train['Bsmt Qual'].value_counts(dropna=False)
# Out:
# TA     887
# Gd     864
# Ex     182
# Fa      60
# NaN     55
# Po       1
# Name: Bsmt Qual, dtype: int64

# %%
# Replace the missing values with TA (as this is the maximum)
train['Bsmt Qual'] = train['Bsmt Qual'].fillna('TA')
train['Bsmt Qual'].value_counts(dropna=False)
# Out:
# TA    942
# Gd    864
# Ex    182
# Fa     60
# Po      1
# Name: Bsmt Qual, dtype: int64

# %% [markdown]
# Handling of `Bsmt Cond` null data.

# %%
# Check the number of elements inside 'Bsmt Cond'
train['Bsmt Cond'].value_counts(dropna=False)
# Out:
# TA     1832
# Gd       89
# Fa       65
# NaN      55
# Po        5
# Ex        3
# Name: Bsmt Cond, dtype: int64

# %%
# Replace the missing values with TA (as this is the maximum)
train['Bsmt Cond'] = train['Bsmt Cond'].fillna('TA')
train['Bsmt Cond'].value_counts(dropna=False)
# Out:
# TA    1887
# Gd      89
# Fa      65
# Po       5
# Ex       3
# Name: Bsmt Cond, dtype: int64

# %% [markdown]
# Handling of `Bsmt Exposure` null data.

# %%
# Check the number of elements inside 'Bsmt Exposure'
train['Bsmt Exposure'].value_counts(dropna=False)
# Out:
# No     1339
# Av      288
# Gd      201
# Mn      163
# NaN      58
# Name: Bsmt Exposure, dtype: int64

# %%
# Replace the missing values with No (as this is the maximum)
train['Bsmt Exposure'] = train['Bsmt Exposure'].fillna('No')
train['Bsmt Exposure'].value_counts(dropna=False)
# Out:
# No    1397
# Av     288
# Gd     201
# Mn     163
# Name: Bsmt Exposure, dtype: int64

# %% [markdown]
# Handling of `BsmtFin Type 1` null data.

# %%
# Check the number of elements inside 'Bsmt Type 1'
train['BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# GLQ    613
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# NaN     55
# Name: BsmtFin Type 1, dtype: int64

# %%
# Replace the missing values with NA (this part is empty most likely because of no basement)# Replace the missing values with 1 (as this is the maximum)
train['BsmtFin Type 1'] = train['BsmtFin Type 1'].fillna(train['BsmtFin Type 1'].mode()[0])
train['BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# GLQ    668
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: BsmtFin Type 1, dtype: int64

# %% [markdown]
# Handling of `BsmtFin SF 1` null data.

# %%
# Check the number of elements inside 'Bsmt Type 1'
train['BsmtFin SF 1'].value_counts(dropna=False)
# Out:
# 0.0      657
# 24.0      17
# 16.0      10
# 300.0      7
# 384.0      7
#         ...
# 70.0       1
# 344.0      1
# 140.0      1
# 472.0      1
# 991.0      1
# Name: BsmtFin SF 1, Length: 820, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['BsmtFin SF 1'] = train['BsmtFin SF 1'].fillna(train['BsmtFin SF 1'].mode()[0])
train['BsmtFin SF 1'].value_counts(dropna=False)
# Out:
# 0.0      658
# 24.0      17
# 16.0      10
# 384.0      7
# 20.0       7
#         ...
# 70.0       1
# 688.0      1
# 472.0      1
# 968.0      1
# 991.0      1
# Name: BsmtFin SF 1, Length: 819, dtype: int64

# %% [markdown]
# Handling of `BsmtFin Type 2` null data.

# %%
# Check the number of elements inside 'Bsmt Type 2'
train['BsmtFin Type 2'].value_counts(dropna=False)
# Out:
# Unf    1747
# Rec      80
# LwQ      60
# NaN      56
# BLQ      48
# ALQ      35
# GLQ      23
# Name: BsmtFin Type 2, dtype: int64

# %%
# Replace the missing values with NA (this part is empty most likely because of no basement)
train['BsmtFin Type 2'] = train['BsmtFin Type 2'].fillna('NA')
train['BsmtFin Type 2'].value_counts(dropna=False)
# Out:
# Unf    1747
# Rec      80
# LwQ      60
# NA       56
# BLQ      48
# ALQ      35
# GLQ      23
# Name: BsmtFin Type 2, dtype: int64

# %% [markdown]
# Handling of `BsmtFin SF 2` null data.

# %%
# Check the number of elements inside 'BsmtFin SF 2'
train['BsmtFin SF 2'].value_counts(dropna=False)
# Out:
# 0.0      1801
# 294.0       5
# 162.0       3
# 539.0       3
# 72.0        3
#          ...
# 712.0       1
# 529.0       1
# 215.0       1
# 252.0       1
# 526.0       1
# Name: BsmtFin SF 2, Length: 206, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['BsmtFin SF 2'] = train['BsmtFin SF 2'].fillna(train['BsmtFin SF 2'].mode()[0])
train['BsmtFin SF 2'].value_counts(dropna=False)
# Out:
# 0.0      1802
# 294.0       5
# 162.0       3
# 539.0       3
# 72.0        3
#          ...
# 712.0       1
# 529.0       1
# 215.0       1
# 252.0       1
# 823.0       1
# Name: BsmtFin SF 2, Length: 205, dtype: int64

# %% [markdown]
# Handling of `Bsmt Unf SF` null data.

# %%
# Check the number of elements inside 'Bsmt Unf SF'
train['Bsmt Unf SF'].value_counts(dropna=False)
# Out:
# 0.0       165
# 384.0      14
# 672.0      11
# 728.0      10
# 816.0       9
#          ...
# 1323.0      1
# 1041.0      1
# 314.0       1
# 892.0       1
# 2062.0      1
# Name: Bsmt Unf SF, Length: 967, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['Bsmt Unf SF'] = train['Bsmt Unf SF'].fillna(train['Bsmt Unf SF'].mode()[0])
train['Bsmt Unf SF'].value_counts(dropna=False)
# Out:
# 0.0       166
# 384.0      14
# 672.0      11
# 728.0      10
# 816.0       9
#          ...
# 1323.0      1
# 1041.0      1
# 314.0       1
# 892.0       1
# 2062.0      1
# Name: Bsmt Unf SF, Length: 966, dtype: int64

# %% [markdown]
# Handling of `Total Bsmt SF` null data.

# %%
# Check the number of elements inside 'Total Bsmt SF'
train['Total Bsmt SF'].value_counts(dropna=False)
# Out:
# 0.0       54
# 864.0     51
# 672.0     20
# 1040.0    20
# 816.0     17
#           ..
# 842.0      1
# 752.0      1
# 1232.0     1
# 1480.0     1
# 1125.0     1
# Name: Total Bsmt SF, Length: 891, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['Total Bsmt SF'] = train['Total Bsmt SF'].fillna(train['Total Bsmt SF'].mode()[0])
train['Total Bsmt SF'].value_counts(dropna=False)
# Out:
# 0.0       55
# 864.0     51
# 672.0     20
# 1040.0    20
# 816.0     17
#           ..
# 2418.0     1
# 842.0      1
# 752.0      1
# 1232.0     1
# 1125.0     1
# Name: Total Bsmt SF, Length: 890, dtype: int64

# %% [markdown]
# Handling of `Bsmt Full Bath` null data.

# %%
# Check the number of elements inside 'Bsmt Full Bath'
train['Bsmt Full Bath'].value_counts(dropna=False)
# Out:
# 0.0    1200
# 1.0     823
# 2.0      22
# 3.0       2
# NaN       2
# Name: Bsmt Full Bath, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['Bsmt Full Bath'] = train['Bsmt Full Bath'].fillna(train['Bsmt Full Bath'].mode()[0])
train['Bsmt Full Bath'].value_counts(dropna=False)
# Out:
# 0.0    1202
# 1.0     823
# 2.0      22
# 3.0       2
# Name: Bsmt Full Bath, dtype: int64

# %% [markdown]
# Handling of `Bsmt Half Bath` null data.

# %%
# Check the number of elements inside 'Bsmt Half Bath'
train['Bsmt Half Bath'].value_counts(dropna=False)
# Out:
# 0.0    1922
# 1.0     121
# 2.0       4
# NaN       2
# Name: Bsmt Half Bath, dtype: int64

# %%
# Replace the missing values with 0 (Most likely the house has no basement)
train['Bsmt Half Bath'] = train['Bsmt Half Bath'].fillna(train['Bsmt Half Bath'].mode()[0])
train['Bsmt Half Bath'].value_counts(dropna=False)
# Out:
# 0.0    1924
# 1.0     121
# 2.0       4
# Name: Bsmt Half Bath, dtype: int64

# %% [markdown]
# Handling of `Garage Type` null data.

# %%
# Check the number of elements inside 'Garage Type'
train['Garage Type'].value_counts(dropna=False)
# Out:
# Attchd     1211
# Detchd      536
# BuiltIn     132
# NaN         113
# Basment      27
# 2Types       19
# CarPort      11
# Name: Garage Type, dtype: int64

# %%
# Replace the missing values with Attchd (as this is the maximum)
train.loc[:,'Garage Type'] = train.loc[:,'Garage Type'].fillna('Attchd')
train.loc[:,'Garage Type'].value_counts(dropna=False)
# Out:
# Attchd     1324
# Detchd      536
# BuiltIn     132
# Basment      27
# 2Types       19
# CarPort      11
# Name: Garage Type, dtype: int64

# %% [markdown]
# Handling of `Garage Yr Blt` null data.

# %%
# Check the number of elements inside 'Garage Yr Blt'
train['Garage Yr Blt'].value_counts(dropna=False)
# Out:
# NaN       114
# 2005.0    105
# 2007.0     84
# 2006.0     80
# 2004.0     72
#          ...
# 1919.0      1
# 1917.0      1
# 1896.0      1
# 1895.0      1
# 1918.0      1
# Name: Garage Yr Blt, Length: 101, dtype: int64

# %%
# Replace the missing values with 2005 (as this is the maximum)
train['Garage Yr Blt'] = train['Garage Yr Blt'].fillna(train['Garage Yr Blt'].mode()[0])
train['Garage Yr Blt'].value_counts(dropna=False)
# Out:
# 2005.0    219
# 2007.0     84
# 2006.0     80
# 2004.0     72
# 2003.0     66
# 1977.0     46
# 1998.0     45
# 2008.0     42
# 2000.0     41
# 2002.0     40
# 1999.0     39
# 1976.0     35
# 1993.0     34
# 1978.0     33
# 1958.0     32
# 1950.0     32
# 1968.0     32
# 1996.0     31
# 1956.0     31
# 1966.0     29
# 2001.0     27
# 1965.0     27
# 1995.0     26
# 1967.0     26
# 1997.0     26
# 1994.0     25
# 1964.0     25
# 1962.0     25
# 1975.0     25
# 1979.0     25
# 1954.0     25
# 1959.0     23
# 1992.0     22
# 1980.0     22
# 1963.0     22
# 1990.0     21
# 1920.0     21
# 1960.0     21
# 1970.0     20
# 1930.0     20
# 1973.0     20
# 1957.0     20
# 1940.0     20
# 1961.0     20
# 1953.0     19
# 1974.0     19
# 1971.0     18
# 1969.0     18
# 1972.0     17
# 2009.0     17
# 1939.0     16
# 1987.0     16
# 1955.0     15
# 1988.0     14
# 1948.0     14
# 1989.0     12
# 1985.0     12
# 1951.0     12
# 1981.0     11
# 1984.0     11
# 1952.0     10
# 1941.0     10
# ...

# %% [markdown]
# Handling of `Garage Finish` null data.

# %%
# Check the number of elements inside 'Garage Finish'
train['Garage Finish'].value_counts(dropna=False)
# Out:
# Unf    849
# RFn    579
# Fin    507
# NaN    114
# Name: Garage Finish, dtype: int64

# %%
# Replace the missing values with Unf (as this is the maximum)
train['Garage Finish'] = train['Garage Finish'].fillna('Unf')
train['Garage Finish'].value_counts(dropna=False)
# Out:
# Unf    963
# RFn    579
# Fin    507
# Name: Garage Finish, dtype: int64

# %% [markdown]
# Handling of `Garage Cars` null data.

# %%
# Check the number of elements inside 'Garage Cars'
train['Garage Cars'].value_counts(dropna=False)
# Out:
# 2.0    1135
# 1.0     524
# 3.0     262
# 0.0     113
# 4.0      13
# NaN       1
# 5.0       1
# Name: Garage Cars, dtype: int64

# %%
# Replace the missing values with 2.0 (as this is the maximum)
train['Garage Cars'] = train['Garage Cars'].fillna(train['Garage Cars'].mode()[0])
train['Garage Cars'].value_counts(dropna=False)
# Out:
# 2.0    1136
# 1.0     524
# 3.0     262
# 0.0     113
# 4.0      13
# 5.0       1
# Name: Garage Cars, dtype: int64

# %% [markdown]
# Handling of `Garage Area` null data.

# %%
# Check the number of elements inside 'Garage Area'
train['Garage Area'].value_counts(dropna=False)
# Out:
# 0.0      113
# 440.0     70
# 576.0     69
# 484.0     52
# 528.0     46
#         ...
# 324.0      1
# 408.0      1
# 406.0      1
# 309.0      1
# 983.0      1
# Name: Garage Area, Length: 513, dtype: int64

# %%
# Replace the missing values with 0.0 (as this is the maximum)
train['Garage Area'] = train['Garage Area'].fillna(train['Garage Area'].mode()[0])
train['Garage Area'].value_counts(dropna=False)
# Out:
# 0.0      114
# 440.0     70
# 576.0     69
# 484.0     52
# 528.0     46
#         ...
# 324.0      1
# 408.0      1
# 406.0      1
# 309.0      1
# 983.0      1
# Name: Garage Area, Length: 512, dtype: int64

# %% [markdown]
# Handling of `Garage Qual` null data.

# %%
# Check the number of elements inside 'Garage Qual'
train['Garage Qual'].value_counts(dropna=False)
# Out:
# TA     1830
# NaN     114
# Fa       82
# Gd       18
# Ex        3
# Po        2
# Name: Garage Qual, dtype: int64

# %%
# Replace the missing values with TA (as this is the maximum)
train['Garage Qual'] = train['Garage Qual'].fillna(train['Garage Qual'].mode()[0])
train['Garage Qual'].value_counts(dropna=False)
# Out:
# TA    1944
# Fa      82
# Gd      18
# Ex       3
# Po       2
# Name: Garage Qual, dtype: int64

# %% [markdown]
# Handling of `Garage Cond` null data.

# %%
# Check the number of elements inside 'Garage Cond'
train['Garage Cond'].value_counts(dropna=False)
# Out:
# TA     1866
# NaN     114
# Fa       47
# Gd       12
# Po        8
# Ex        2
# Name: Garage Cond, dtype: int64

# %%
# Replace the missing values with TA (as this is the maximum)
train.loc[:,'Garage Cond'] = train.loc[:,'Garage Cond'].fillna('TA')
train.loc[:,'Garage Cond'].value_counts(dropna=False)
# Out:
# TA    1980
# Fa      47
# Gd      12
# Po       8
# Ex       2
# Name: Garage Cond, dtype: int64

# %% [markdown]
# Handling of `BsmtFin Type 1` null data.

# %%
# Check the number of elements inside 'Garage Cond'
train['BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# GLQ    668
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: BsmtFin Type 1, dtype: int64

# %%
# Replace the missing values with 1 (as this is the maximum)
train['BsmtFin Type 1'] = train['BsmtFin Type 1'].fillna(train['BsmtFin Type 1'].mode()[0])
train['BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# GLQ    668
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: BsmtFin Type 1, dtype: int64

# %%
# Check if there is anymore null values
train.isnull().sum()
# Out:
# Id                 0
# PID                0
# MS SubClass        0
# MS Zoning          0
# Lot Frontage       0
# Lot Area           0
# Street             0
# Lot Shape          0
# Land Contour       0
# Utilities          0
# Lot Config         0
# Land Slope         0
# Neighborhood       0
# Condition 1        0
# Condition 2        0
# Bldg Type          0
# House Style        0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Roof Style         0
# Roof Matl          0
# Exterior 1st       0
# Exterior 2nd       0
# Mas Vnr Type       0
# Mas Vnr Area       0
# Exter Qual         0
# Exter Cond         0
# Foundation         0
# Bsmt Qual          0
# Bsmt Cond          0
# Bsmt Exposure      0
# BsmtFin Type 1     0
# BsmtFin SF 1       0
# BsmtFin Type 2     0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Heating            0
# Heating QC         0
# Central Air        0
# Electrical         0
# ...

# %% [markdown]
# CONCLUSION:
#
# After confirmation, all the null values of the data have been cleaned and replaced (mostly replaced by 0 or the maximum occurence of other data).

# %% [markdown]
# # Look into non-numerical data

# %%
train.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# BsmtFin Type 1      object
# ...

# %%
train.select_dtypes([np.object])
# Out:
#      MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0           RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 1           RL   Pave       IR1          Lvl    AllPub    CulDSac        Gtl
# 2           RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 3           RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 4           RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...    ...       ...          ...       ...        ...        ...
# 2046        RL   Pave       IR1          HLS    AllPub     Inside        Gtl
# 2047        RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 2048        RL   Pave       Reg          Bnk    AllPub     Inside        Gtl
# 2049        RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 2050        RL   Pave       Reg          Lvl    AllPub     Inside        Gtl
#
# ...

# %% [markdown]
# We look into the number of occurence of each elements inside the non-numerical variables:

# %% [markdown]
# Handling of `MS Zoning` data.

# %%
sns.countplot(data = train , x='MS Zoning')

# %% [markdown]
# Handling of `Street` data.

# %%
sns.countplot(data = train , x='Street')

# %% [markdown]
# Handling of `Lot Shape` data.

# %%
sns.countplot(data = train , x='Lot Shape')

# %% [markdown]
# Handling of `Land Contour` data.

# %%
sns.countplot(data = train , x='Land Contour')

# %% [markdown]
# Handling of `Utilities` data.

# %%
sns.countplot(data = train , x='Utilities')

# %% [markdown]
# Handling of `Lot Config` data.

# %%
sns.countplot(data = train , x='Lot Config')

# %% [markdown]
# Handling of `Land Slope` data.

# %%
sns.countplot(data = train , x='Land Slope')

# %% [markdown]
# Handling of `Neighborhood` data.

# %%
plt.figure(figsize=(8, 7))
sns.countplot(data = train , y='Neighborhood')

# %% [markdown]
# Handling of `Condition 1` data.

# %%
sns.countplot(data = train , x='Condition 1')

# %% [markdown]
# Handling of `Condition 2` data.

# %%
sns.countplot(data = train , x='Condition 2')

# %% [markdown]
# Handling of `Bldg Type` data.

# %%
sns.countplot(data = train , x='Bldg Type')

# %% [markdown]
# Handling of `House Style` data.

# %%
sns.countplot(data = train , x='House Style')

# %% [markdown]
# Handling of `Roof Style` data.

# %%
sns.countplot(data = train , x='Roof Style')

# %% [markdown]
# Handling of `Roof Matl` data.

# %%
sns.countplot(data = train , x='Roof Matl')

# %% [markdown]
# Handling of `Exterior 1st` data.

# %%
plt.figure(figsize=(8, 7))
sns.countplot(data = train , y='Exterior 1st')

# %% [markdown]
# Handling of `Exterior 2nd` data.

# %%
plt.figure(figsize=(8, 7))
sns.countplot(data = train , y='Exterior 2nd')

# %% [markdown]
# Handling of `Mas Vnr Type` data.

# %%
sns.countplot(data = train , x='Mas Vnr Type')

# %% [markdown]
# Handling of `Exter Qual` data.

# %%
sns.countplot(data = train , x='Exter Qual')

# %% [markdown]
# Handling of `Exter Cond` data.

# %%
sns.countplot(data = train , x='Exter Cond')

# %% [markdown]
# Handling of `Foundation` data.

# %%
sns.countplot(data = train , x='Foundation')

# %% [markdown]
# Handling of `Bsmt Qual` data.

# %%
sns.countplot(data = train , x='Bsmt Qual')

# %% [markdown]
# Handling of `Bsmt Exposure` data.

# %%
sns.countplot(data = train , x='Bsmt Exposure')

# %% [markdown]
# Handling of `BsmtFin Type 1` data.

# %%
sns.countplot(data = train , x='BsmtFin Type 1')

# %% [markdown]
# Handling of `BsmtFin Type 2` data.

# %%
sns.countplot(data = train , x='BsmtFin Type 2')

# %% [markdown]
# Handling of `Heating` data.

# %%
sns.countplot(data = train , x='Heating')

# %% [markdown]
# Handling of `Heating QC` data.

# %%
sns.countplot(data = train , x='Heating QC')

# %% [markdown]
# Handling of `Central Air` data.

# %%
sns.countplot(data = train , x='Central Air')

# %% [markdown]
# Handling of `Electrical` data.

# %%
sns.countplot(data = train , x='Electrical')

# %% [markdown]
# Handling of `Kitchen Qual` data.

# %%
sns.countplot(data = train , x='Kitchen Qual')

# %% [markdown]
# Handling of `Functional` data.

# %%
sns.countplot(data = train , x='Functional')

# %% [markdown]
# Handling of `Garage Type` data.

# %%
sns.countplot(data = train , x='Garage Type')

# %% [markdown]
# Handling of `Garage Finish` data.

# %%
sns.countplot(data = train , x='Garage Finish')

# %% [markdown]
# Handling of `Garage Qual` data.

# %%
sns.countplot(data = train , x='Garage Qual')

# %% [markdown]
# Handling of `Garage Cond` data.

# %%
sns.countplot(data = train , x='Garage Cond')

# %% [markdown]
# Handling of `Paved Drive` data.

# %%
sns.countplot(data = train , x='Paved Drive')

# %% [markdown]
# Handling of `Sale Type` data.

# %%
sns.countplot(data = train , x='Sale Type')

# %% [markdown]
# CONCLUSION:

# %% [markdown]
# Majority of the variable is predominant by one element (an element showing > 75%), it seems to be alright to drop that variable as its element does not show much impact on others. Besides that, there are some variables which show the effect of different elements, it is worthwhile to look into those variables.

# %% [markdown]
# Nominal Variables:
#
# - House Style
# - Exterior 1st
# - Foundation
# - Neighborhood
# - Exterior 2nd
# - Mas Vnr Type
# - Garage Type

# %% [markdown]
# Ordinal Variables:
#
# - Lot Shape
# - Exter Qual
# - Bsmt Qual
# - Bsmt Fin Type 1
# - Heating QC
# - Kitchen Qual
# - Garage Finish

# %% [markdown]
# # Mapping the ordinal data that we are interested

# %% [markdown]
# Mapping the `Lot Shape` data.

# %%
train.loc[:,'Lot Shape'].value_counts(dropna=False)
# Out:
# Reg    1295
# IR1     691
# IR2      55
# IR3       8
# Name: Lot Shape, dtype: int64

# %%
Lot_dict = {'Reg':1 , 'IR1':2 , 'IR2':3 , 'IR3':4}

# %%
train['Lot Shape'] = train['Lot Shape'].map(Lot_dict)

# %%
train.loc[:,'Lot Shape'].value_counts(dropna=False)
# Out:
# 1    1295
# 2     691
# 3      55
# 4       8
# Name: Lot Shape, dtype: int64

# %% [markdown]
# Mapping the `Exter Qual` data.

# %%
train.loc[:,'Exter Qual'].value_counts(dropna=False)
# Out:
# TA    1247
# Gd     697
# Ex      79
# Fa      26
# Name: Exter Qual, dtype: int64

# %%
Exter_dict = {'Ex':1 , 'Gd':2 , 'TA':3 , 'Fa':4}

# %%
train['Exter Qual'] = train['Exter Qual'].map(Exter_dict)

# %%
train.loc[:,'Exter Qual'].value_counts(dropna=False)
# Out:
# 3    1247
# 2     697
# 1      79
# 4      26
# Name: Exter Qual, dtype: int64

# %% [markdown]
# Mapping the `Bsmt Qual` data.

# %%
train.loc[:,'Bsmt Qual'].value_counts(dropna=False)
# Out:
# TA    942
# Gd    864
# Ex    182
# Fa     60
# Po      1
# Name: Bsmt Qual, dtype: int64

# %%
Bsmt_dict = {'Ex':1 , 'Gd':2 , 'TA':3 , 'Fa':4 , 'Po':5 , 'Na':6}

# %%
train['Bsmt Qual'] = train['Bsmt Qual'].map(Bsmt_dict)

# %%
train.loc[:,'Bsmt Qual'].value_counts(dropna=False)
# Out:
# 3    942
# 2    864
# 1    182
# 4     60
# 5      1
# Name: Bsmt Qual, dtype: int64

# %% [markdown]
# Mapping the `BsmtFin Type 1` data.

# %%
train.loc[:,'BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# GLQ    668
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: BsmtFin Type 1, dtype: int64

# %%
BsmtFin_dict = {'GLQ':1 , 'ALQ':2 , 'BLQ':3 , 'Rec':4 , 'LwQ':5 , 'Unf':6}

# %%
train['BsmtFin Type 1'] = train['BsmtFin Type 1'].map(BsmtFin_dict)

# %%
train.loc[:,'BsmtFin Type 1'].value_counts(dropna=False)
# Out:
# 1    668
# 6    603
# 2    293
# 3    200
# 4    183
# 5    102
# Name: BsmtFin Type 1, dtype: int64

# %% [markdown]
# Mapping the `Heating QC` data

# %%
train.loc[:,'Heating QC'].value_counts(dropna=False)
# Out:
# Ex    1063
# TA     597
# Gd     319
# Fa      67
# Po       3
# Name: Heating QC, dtype: int64

# %%
Heating_dict = {'Ex':1 , 'Gd':2 , 'TA':3 , 'Fa':4 , 'Po':5}

# %%
train['Heating QC'] = train['Heating QC'].map(Heating_dict)

# %%
train.loc[:,'Heating QC'].value_counts(dropna=False)
# Out:
# 1    1063
# 3     597
# 2     319
# 4      67
# 5       3
# Name: Heating QC, dtype: int64

# %% [markdown]
# Mapping the `Kitchen Qual` data

# %%
train.loc[:,'Kitchen Qual'].value_counts(dropna=False)
# Out:
# TA    1047
# Gd     806
# Ex     149
# Fa      47
# Name: Kitchen Qual, dtype: int64

# %%
Kitchen_dict = {'Ex':1 , 'Gd':2 , 'TA':3 , 'Fa':4 , 'Po':5}

# %%
train['Kitchen Qual'] = train['Kitchen Qual'].map(Kitchen_dict)

# %%
train.loc[:,'Kitchen Qual'].value_counts(dropna=False)
# Out:
# 3    1047
# 2     806
# 1     149
# 4      47
# Name: Kitchen Qual, dtype: int64

# %% [markdown]
# Mapping the `Garage Finish` data

# %%
train.loc[:,'Garage Finish'].value_counts(dropna=False)
# Out:
# Unf    963
# RFn    579
# Fin    507
# Name: Garage Finish, dtype: int64

# %%
Garage_dict = {'Fin':1 , 'RFn':2 , 'Unf':3}

# %%
train['Garage Finish'] = train['Garage Finish'].map(Garage_dict)

# %%
train.loc[:,'Garage Finish'].value_counts(dropna=False)
# Out:
# 3    963
# 2    579
# 1    507
# Name: Garage Finish, dtype: int64

# %% [markdown]
# CONCLUSIONS:

# %% [markdown]
# After mapping those variables we are interested, we will include them in our correlation graph later to see how are these variables correlated with our Sale Price.

# %% [markdown]
# # Plotting the nominal data that we are interested

# %% [markdown]
# Plotting the `House Style` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='House Style' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Exterior 1st` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Exterior 1st' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Foundation` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Foundation' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Neighborhood` data.

# %%
plt.figure(figsize=(15, 6))
plt.xticks(rotation=45)
sns.boxplot(x='Neighborhood' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Exterior 2nd` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Exterior 2nd' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Mas Vnr Type` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Mas Vnr Type' , y='SalePrice', data=train)

# %% [markdown]
# Plotting the `Garage Type` data.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Garage Type' , y='SalePrice', data=train)

# %% [markdown]
# CONCLUSION:

# %% [markdown]
# By looking at the Interquantile Range (Q1 - Q3) of the 7 box plots, it seems like some of the element in these 7 box plots may affect the Sale Price as some of them have a different Interquantile Range as the others.
#
# We will include all these 7 variables in our model, and we will check the coefficient of the relevant models to see if there is any significant impact of them to the Sale Price.

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(train.corr() , cmap='icefire',mask=np.triu(train.corr()))

# %%
sp = train.corr()[['SalePrice']]

# %%
sp.sort_values(by='SalePrice')
# Out:
#                  SalePrice
# Exter Qual       -0.715048
# Kitchen Qual     -0.694295
# Bsmt Qual        -0.683897
# Garage Finish    -0.549204
# Heating QC       -0.458636
# BsmtFin Type 1   -0.285509
# PID              -0.255068
# Enclosed Porch   -0.135713
# Kitchen AbvGr    -0.125472
# Overall Cond     -0.097093
# MS SubClass      -0.087331
# Id               -0.051416
# Bsmt Half Bath   -0.045534
# Low Qual Fin SF  -0.041608
# Yr Sold          -0.015174
# Misc Val         -0.010323
# BsmtFin SF 2      0.016398
# Pool Area         0.025805
# Mo Sold           0.032508
# 3Ssn Porch        0.048721
# Screen Porch      0.134555
# Bedroom AbvGr     0.137145
# Bsmt Unf SF       0.190883
# 2nd Flr SF        0.248826
# Half Bath         0.283372
# Bsmt Full Bath    0.284433
# Lot Shape         0.296743
# Lot Area          0.303744
# Wood Deck SF      0.327629
# Lot Frontage      0.328981
# Open Porch SF     0.338545
# BsmtFin SF 1      0.446103
# Garage Yr Blt     0.447781
# ...

# %% [markdown]
# # Our goal is to predict price, list variables that i think will predict price in an SLR model.

# %% [markdown]
# Based on the correlation between SalePrice and various variables, i will choose those variables of correlation values > 0.3 & correlation values < -0.3 to be in an SLR model. Also, i will add in the 7 nomial variables inside the model.
#
# We will then check the model and its coefficient, so that we can decide easily which variable has a higher impact to the Sale Price.

# %%
X1 = train[['Overall Qual' , 'Gr Liv Area' , 'Total Bsmt SF' , 'Garage Area' , 
          'Garage Cars' , '1st Flr SF' , 'Year Built' , 'Year Remod/Add' ,
          'Full Bath' , 'Mas Vnr Area' , 'TotRms AbvGrd' , 'Fireplaces' ,
          'Garage Yr Blt' , 'BsmtFin SF 1' , 'Open Porch SF' , 'Lot Frontage' ,
          'Wood Deck SF' , 'Lot Area' , 'Exter Qual' , 'Kitchen Qual' , 
          'Bsmt Qual' , 'Garage Finish' , 'Heating QC' , 'BsmtFin Type 1' ,
          'House Style' , 'Exterior 1st' , 'Foundation' , 'Neighborhood' ,
          'Exterior 2nd' , 'Mas Vnr Type' , 'Garage Type']]

# %%
y1 = train['SalePrice']

# %%
X1.isnull().sum()
# Out:
# Overall Qual      0
# Gr Liv Area       0
# Total Bsmt SF     0
# Garage Area       0
# Garage Cars       0
# 1st Flr SF        0
# Year Built        0
# Year Remod/Add    0
# Full Bath         0
# Mas Vnr Area      0
# TotRms AbvGrd     0
# Fireplaces        0
# Garage Yr Blt     0
# BsmtFin SF 1      0
# Open Porch SF     0
# Lot Frontage      0
# Wood Deck SF      0
# Lot Area          0
# Exter Qual        0
# Kitchen Qual      0
# Bsmt Qual         0
# Garage Finish     0
# Heating QC        0
# BsmtFin Type 1    0
# House Style       0
# Exterior 1st      0
# Foundation        0
# Neighborhood      0
# Exterior 2nd      0
# Mas Vnr Type      0
# Garage Type       0
# dtype: int64

# %% [markdown]
# # Use Get_Dummies to convert the 3 Nomial variables

# %%
# Check the initial shape
X1.shape
# Out:
# (2049, 31)

# %%
# Get_Dummies
X1 = pd.get_dummies(X1, columns=['House Style' , 'Exterior 1st' , 'Foundation' , 'Neighborhood' ,
                                'Exterior 2nd' , 'Mas Vnr Type' , 'Garage Type'])

# %%
# Check the new shape after get_dummies
X1.shape
# Out:
# (2049, 106)

# %%
# Check the new columns after get_dummies
X1.columns
# Out:
# Index(['Overall Qual', 'Gr Liv Area', 'Total Bsmt SF', 'Garage Area',
#        'Garage Cars', '1st Flr SF', 'Year Built', 'Year Remod/Add',
#        'Full Bath', 'Mas Vnr Area',
#        ...
#        'Mas Vnr Type_BrkCmn', 'Mas Vnr Type_BrkFace', 'Mas Vnr Type_None',
#        'Mas Vnr Type_Stone', 'Garage Type_2Types', 'Garage Type_Attchd',
#        'Garage Type_Basment', 'Garage Type_BuiltIn', 'Garage Type_CarPort',
#        'Garage Type_Detchd'],
#       dtype='object', length=106)

# %% [markdown]
# # Train-test split

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=50)

# %%
X1_train.shape
# Out:
# (1536, 106)

# %%
y1_train.shape
# Out:
# (1536,)

# %% [markdown]
# # Scaling data

# %%
scaler = StandardScaler()

X1_train_scaled = scaler.fit_transform(X1_train)
X1_test_scaled = scaler.fit_transform(X1_test)

# %% [markdown]
# # Adjusted R-Squared calculation

# %% [markdown]
# Instead of calculating R-Squared, we can use adjusted R-Squared, this is more suitable for a large dataset.

# %% [markdown]
# #### Formula for adjusted R-Squared
#
# $$R_(adj)^ 2 = 1 - {\frac{(1-R^2)(n-1)}{n-k-1}}$$
#
# - n = No. of data
# - k = No. of variables

# %% [markdown]
# # Linear Regression model

# %%
lr = LinearRegression()

# %%
lr.fit(X1_train_scaled, y1_train)
# Out:
# LinearRegression()

# %%
# Train score (R2) for Linear Regression model on seen data
lr.score(X1_train_scaled , y1_train)
# Out:
# 0.9065303127621913

# %%
# r2 for Linear Regression
lr_r2 = cross_val_score(lr, X1_train_scaled, y1_train, cv=5, scoring='r2').mean()

# %%
lr_r2
# Out:
# -9.468007889425259e+23

# %%
# Train score (R2) for Linear Regression model
cross_val_score(lr, X1_train_scaled, y1_train, cv=5).mean()
# Out:
# -9.468007889425259e+23

# %%
# Train score (R2) for Linear Regression model on unseen data
cross_val_score(lr , X1_train_scaled , y1_train , cv=5)
# Out:
# array([-1.18097966e+21, -1.00098028e+20, -1.93196846e+21, -3.61449489e+21,
#        -4.72717640e+24])

# %%
# Estimated RMSE for Linear Regression model
-cross_val_score(lr, X1_train_scaled , y1_train , cv=5 , scoring ='neg_root_mean_squared_error').mean()
# Out:
# 3.970711966070825e+16

# %%
# rmse = np.sqrt(-cross_val_score(rid_cv), X1_train_scaled, y1)

# -cross_val_score(rid_cv, X1_train_scaled , y1_train , cv=5 , scoring ='neg_root_mean_squared_error').mean()

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV

# %%
r_alphas = np.linspace(10, 30, 200)

rid_cv = RidgeCV(alphas = r_alphas , cv=5)
rid_cv = rid_cv.fit(X1_train_scaled , y1_train)
rmse_rid_cv = -cross_val_score(rid_cv, X1_train_scaled , y1_train , cv=5 , scoring ='neg_root_mean_squared_error').mean()

# %%
rid_cv_r2 = cross_val_score(rid_cv, X1_train_scaled, y1_train, cv=5, scoring='r2').mean()

# %%
rid_cv_r2
# Out:
# 0.8872472482718605

# %%
print(f'Best Ridge Alpha: {rid_cv.alpha_}')
# Out:
# Best Ridge Alpha: 30.0

# %%
print(f'Best Ridge R2: {rid_cv.score(X1_train_scaled , y1_train)}')
# Out:
# Best Ridge R2: 0.9060932378826482

# %%
print(f'Best Ridge RMSE: {rmse_rid_cv}')
# Out:
# Best Ridge RMSE: 27468.38349450699

# %% [markdown]
# # Lasso

# %%
l_alphas = np.linspace(150 , 220 , 150)

las_cv = LassoCV(alphas=l_alphas , cv=5 , max_iter = 1000)
las_cv = las_cv.fit(X1_train_scaled , y1_train)
rmse_las_cv = -cross_val_score(las_cv, X1_train_scaled , y1_train , cv=5 , scoring ='neg_root_mean_squared_error').mean()

# %%
print(f'Best Lasso Alpha: {las_cv.alpha_}')
# Out:
# Best Lasso Alpha: 220.0

# %%
las_cv_r2 = cross_val_score(las_cv, X1_train_scaled, y1_train, cv=5, scoring='r2').mean()

# %%
las_cv_r2
# Out:
# 0.8896526982470594

# %%
print(f'Best Lasso R2: {las_cv.score(X1_train_scaled , y1_train)}')
# Out:
# Best Lasso R2: 0.9054465242549485

# %%
print(f'Best Lasso RMSE: {rmse_las_cv}')
# Out:
# Best Lasso RMSE: 27181.19923333779

# %% [markdown]
# # ElasticNet CV

# %%
enet_alphas = np.arange(0.5, 1.0, 0.005)
enet_ratio = 0.5
enet_cv = ElasticNetCV(alphas=enet_alphas, l1_ratio=enet_ratio, cv=5)
enet_cv = enet_model.fit(X1_train_scaled, y1_train)

# %%
enet_cv_r2 = cross_val_score(enet_cv, X1_train_scaled, y1_train, cv=5, scoring='r2').mean()

# %%
enet_cv_r2
# Out:
# 0.8860330100025273

# %%
rmse_enet_cv = -cross_val_score(enet_cv, X1_train_scaled , y1_train , cv=5 , scoring ='neg_root_mean_squared_error').mean()

# %%
rmse_enet_cv
# Out:
# 27624.991006259806

# %% [markdown]
# # Comparing different models

# %% [markdown]
# Linear Regression:
# - R2 is 0.878
# - RMSE is 3,339,348,934,667,419

# %% [markdown]
# Ridge CV
# - R2 is 0.878 19
# - RMSE is 29,681

# %% [markdown]
# Lasso CV
# - R2 is 0.878 08
# - RMSE is 29,532

# %% [markdown]
# ElasticNet CV
#
# - R2 is 0.886
# - RMSE is 27,624

# %% [markdown]
# # Model Fitting and Evaluation

# %%
pd.Series(rid_cv.coef_, index=X1.columns).plot.bar(figsize=(15,7))

# %%
{X1.columns[i]: rid_cv.coef_[i] for i in range(len(X1.columns))}
# Out:
# {'Overall Qual': 14125.488444327231,
#  'Gr Liv Area': 18055.1685951715,
#  'Total Bsmt SF': 9346.476161964734,
#  'Garage Area': 7348.4104944353,
#  'Garage Cars': -1357.0769522685594,
#  '1st Flr SF': 1605.4446672837807,
#  'Year Built': 2698.786714148656,
#  'Year Remod/Add': 3720.5946035050188,
#  'Full Bath': -1769.5236036662611,
#  'Mas Vnr Area': 7812.07020758475,
#  'TotRms AbvGrd': 1232.029549870968,
#  'Fireplaces': 3514.5489367873934,
#  'Garage Yr Blt': 346.972824047655,
#  'BsmtFin SF 1': 10625.520373681446,
#  'Open Porch SF': 1125.8152082092397,
#  'Lot Frontage': 4121.438296769873,
#  'Wood Deck SF': 2117.2618492946085,
#  'Lot Area': 5945.8820397950785,
#  'Exter Qual': -6301.112943065461,
#  'Kitchen Qual': -5942.501558004985,
#  'Bsmt Qual': -4090.5208336430096,
#  'Garage Finish': -525.5222820641293,
#  'Heating QC': -1753.8870052513905,
#  'BsmtFin Type 1': 432.19905157192704,
#  'House Style_1.5Fin': -619.711594301105,
# ...

# %% [markdown]
# CONCLUSION:
#
# Based on the coefficient, i intend to further modify the model by dropping those variabes with an average coefficient of less than 1000 (i.e. dropping `Garage Type` , `Exterior 2nd` , `Neighborhood` , `Foundation` , `Exterior 1st` , `House Style` , `Bsmt Fin Type 1` & `Garage Finish`).

# %% [markdown]
# # Final Model

# %%
X2 = train[['Overall Qual' , 'Gr Liv Area' , 'Total Bsmt SF' , 'Garage Area' , 
          'Garage Cars' , '1st Flr SF' , 'Year Built' , 'Year Remod/Add' ,
          'Full Bath' , 'Mas Vnr Area' , 'TotRms AbvGrd' , 'Fireplaces' ,
          'Garage Yr Blt' , 'BsmtFin SF 1' , 'Open Porch SF' , 'Lot Frontage' ,
          'Wood Deck SF' , 'Lot Area' , 'Exter Qual' , 'Kitchen Qual' , 
          'Bsmt Qual' , 'Heating QC' , 'Mas Vnr Type']]

# %%
y2 = train['SalePrice']

# %%
X2.shape
# Out:
# (2049, 23)

# %%
y2.shape
# Out:
# (2049,)

# %% [markdown]
# # Use Linear Regression to check how well is our model

# %%
lr = LinearRegression()

# %%
# Fit Linear Regression of our model
lr.fit(X , y)

# %%
# Intepret the intercept and the slope
lr.intercept_

# %%
lr.coef_

# %%
{X.columns[i]: lr.coef_[i] for i in range(len(X.columns))}

# %% [markdown]
# From the Linear Regression model, we can see that the `Lot Area` is insignificant, we can construct a new model without that variablle.

# %%
X1 = train[['Overall Qual' , 'Gr Liv Area' , 'Total Bsmt SF' , 'Garage Area' , 
          'Garage Cars' , '1st Flr SF' , 'Year Built' , 'Year Remod/Add' ,
          'Full Bath' , 'Mas Vnr Area' , 'TotRms AbvGrd' , 'Fireplaces' ,
          'Garage Yr Blt' , 'BsmtFin SF 1' , 'Open Porch SF' , 'Lot Frontage' ,
          'Wood Deck SF' , 'Bsmt Full Bath' , 'Half Bath' , '2nd Flr SF' ,
          'Bsmt Unf SF']]

# %%
y1 = train['SalePrice']

# %% [markdown]
# Check the new model and its residual.

# %%
lr.fit(X1 , y1)

# %%
lr.coef_

# %%
lr.intercept_

# %%
{X1.columns[i]: lr.coef_[i] for i in range(len(X1.columns))}

# %% [markdown]
# # Using the new model, calculate and plot the residuals

# %%
predictions = lr.predict(X1)
len(predictions)

# %%
# calculate residuals
residuals = y - predictions
residuals

# %%
plt.scatter(predictions , residuals)
plt.axhline(0 , color='orange')
