# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# Define the problem you are finding answers for from the data given.

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('../data/sat_2017.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Read the first 10 rows of SAT 2017 data
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#Read the first 10 rows of ACT 2017 data
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# In the first glance, ACT includes science exam while SAT does not.
#
# Also, some of the states recongnized one exam more over another. Because of that, some of the states have ACT particpating rate of 100% and SAT participation rate quite low, or vice versa.

# %% [markdown]
# #### 4a. Does the data look complete?

# %%
# Use heatmap to find if there is any missing data for SAT 2017
sns.heatmap(sat_2017.isnull())

# %%
# Use heatmap to find if there is any missing data for ACT 2017
sns.heatmap(act_2017.isnull())

# %% [markdown]
# Answer:
#
# By using a heatmap to view,there is no empty data, so it is complete. Next, we inspect the statistical values for the numerical columns.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
# Look at a summary of SAT 2017 data
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
# Look at a summary of ACT 2017 data
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# #Answer:
# The possible score for SAT is 400 - 1600, each SAT section is scored between 200 and 800 points.
#
# For ACT, each test score (English, Math, Reading & Science) range from 1 to 36. The composite score is the average of your four test scores, rounded to the nearest whole number.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# Glance through SAT 2017 result.
sat_2017
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
# For Maryland's Math score, it seems to be wrong as it is below the range.
# After checking the result from the website, the correct Math score is 524.

sat_2017.loc[sat_2017['State'] == 'Maryland' , ['Math']] = 524

# %%
sat_2017[(sat_2017['State'] == 'Maryland')]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
# Glance through ACT 2017 result
act_2017
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
# In state Wyoming, the Composite score is wrong as it shows 20.2x
act_2017.loc[act_2017['State'] == 'Wyoming' , ['Composite']] = 20.2

# %%
act_2017[(act_2017['State'] == 'Wyoming')]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
# Check the data types for SAT 2017 Data
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Check the data types for ACT 2017 Data
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# #Answer:
# For ACT 2017 data, the Composite result is displayed as an object type, different from other subtests result. It should be shown as float type.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
act_2017cln = pd.DataFrame(act_2017)

# %%
sat_2017cln = pd.DataFrame(sat_2017)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Change the data type of Composite 
act_2017cln['Composite'] = pd.to_numeric(act_2017['Composite'], errors='coerce')

# %%
def percentage_string_to_float(x):
    return float(x[:-1])

# %%
act_2017cln.loc[:,'Participation'] = act_2017.loc[:,'Participation'].apply(percentage_string_to_float)

# %%
sat_2017cln.loc[:,'Participation'] = sat_2017.loc[:,'Participation'].apply(percentage_string_to_float)

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
act_2017cln.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_2017cln.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
import string
# the string library has default strings that contain all letters or numbers
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase

# %%
act_2017cln.columns = act_2017cln.columns.str.lower()

# %%
sat_2017cln.columns = sat_2017cln.columns.str.lower()

# %%
#Check current columns
act_2017cln.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
#Check current columns
sat_2017cln.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
#Rename the column names of ACT
act_2017cln.rename(columns={
    'participation' : 'act_participation_rate_2017',
    'english' : 'act_english_2017',
    'math' : 'act_math_2017',
    'reading' : 'act_reading_2017',
    'science' : 'act_science_2017',
    'composite' : 'act_composite_2017'
} , inplace=True)

# %%
#Rename the column names of SAT
sat_2017cln.rename(columns={
    'participation' : 'sat_participation_rate_2017',
    'evidence-based reading and writing' : 'sat_ebrw_2017',
    'math' : 'sat_math_2017',
    'total' : 'sat_total_2017'
} , inplace=True)

# %%
act_2017cln.head()
# Out:
#       state  act_participation_rate_2017  act_english_2017  act_math_2017  \
# 0  National                         60.0              20.3           20.7
# 1   Alabama                        100.0              18.9           18.4
# 2    Alaska                         65.0              18.7           19.8
# 3   Arizona                         62.0              18.6           19.8
# 4  Arkansas                        100.0              18.9           19.0
#
#    act_reading_2017  act_science_2017  act_composite_2017
# 0              21.4              21.0                21.0
# 1              19.7              19.4                19.2
# 2              20.4              19.9                19.8
# 3              20.1              19.8                19.7
# 4              19.7              19.5                19.4

# %%
sat_2017cln.head()
# Out:
#         state  sat_participation_rate_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                          5.0            593            572
# 1      Alaska                         38.0            547            533
# 2     Arizona                         30.0            563            553
# 3    Arkansas                          3.0            614            594
# 4  California                         53.0            531            524
#
#    sat_total_2017
# 0            1165
# 1            1080
# 2            1116
# 3            1208
# 4            1055

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
act_2017cln
# Out:
#                    state  act_participation_rate_2017  act_english_2017  \
# 0               National                         60.0              20.3
# 1                Alabama                        100.0              18.9
# 2                 Alaska                         65.0              18.7
# 3                Arizona                         62.0              18.6
# 4               Arkansas                        100.0              18.9
# 5             California                         31.0              22.5
# 6               Colorado                        100.0              20.1
# 7            Connecticut                         31.0              25.5
# 8               Delaware                         18.0              24.1
# 9   District of Columbia                         32.0              24.4
# 10               Florida                         73.0              19.0
# 11               Georgia                         55.0              21.0
# ...

# %%
sat_2017cln
# Out:
#                    state  sat_participation_rate_2017  sat_ebrw_2017  \
# 0                Alabama                          5.0            593
# 1                 Alaska                         38.0            547
# 2                Arizona                         30.0            563
# 3               Arkansas                          3.0            614
# 4             California                         53.0            531
# 5               Colorado                         11.0            606
# 6            Connecticut                        100.0            530
# 7               Delaware                        100.0            503
# 8   District of Columbia                        100.0            482
# 9                Florida                         83.0            520
# 10               Georgia                         61.0            535
# 11                Hawaii                         55.0            544
# 12                 Idaho                         93.0            513
# ...

# %% [markdown]
# act_2017cln has one extra row of National result, needs to remove it.

# %%
act_2017cln = act_2017cln.loc[(act_2017cln.loc[:,'state'] != 'National'),:]

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
combined_2017 = pd.merge(sat_2017cln , act_2017cln , on='state')

# %%
combined_2017.head()
# Out:
#         state  sat_participation_rate_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                          5.0            593            572
# 1      Alaska                         38.0            547            533
# 2     Arizona                         30.0            563            553
# 3    Arkansas                          3.0            614            594
# 4  California                         53.0            531            524
#
#    sat_total_2017  act_participation_rate_2017  act_english_2017  \
# 0            1165                        100.0              18.9
# 1            1080                         65.0              18.7
# 2            1116                         62.0              18.6
# 3            1208                        100.0              18.9
# 4            1055                         31.0              22.5
#
#    act_math_2017  act_reading_2017  act_science_2017  act_composite_2017
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
#Read the files
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018_updated.csv')

# %%
#Read the first 10 rows of SAT 2018 data
sat_2018.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            6%                                 595
# 1                Alaska           43%                                 562
# 2               Arizona           29%                                 577
# 3              Arkansas            5%                                 592
# 4            California           60%                                 540
# 5              Colorado          100%                                 519
# 6           Connecticut          100%                                 535
# 7              Delaware          100%                                 505
# 8  District of Columbia           92%                                 497
# 9               Florida           56%                                 550
#
#    Math  Total
# 0   571   1166
# 1   544   1106
# 2   572   1149
# 3   576   1169
# 4   536   1076
# 5   506   1025
# 6   519   1053
# 7   492    998
# ...

# %%
#Read the first 10 rows of ACT 2018 data
act_2018.head(10)
# Out:
#                   State  Percentage of Students Tested  \
# 0               Alabama                            100
# 1                Alaska                             33
# 2               Arizona                             66
# 3              Arkansas                            100
# 4            California                             27
# 5              Colorado                             30
# 6           Connecticut                             26
# 7              Delaware                             17
# 8  District of Columbia                             32
# 9               Florida                             66
#
#    Average Composite Score  Average English Score  Average Math Score  \
# 0                     19.1                   18.9                18.3
# 1                     20.8                   19.8                20.6
# 2                     19.2                   18.2                19.4
# 3                     19.4                   19.1                18.9
# ...

# %% [markdown]
# # Does the data looks complete?

# %%
# Use heatmap to find if there is any missing data for SAT 2018
sns.heatmap(sat_2018.isnull())

# %%
# Use heatmap to find if there is any missing data for ACT 2018
sns.heatmap(act_2018.isnull())

# %% [markdown]
# #Answer:
#
# By using heatmap to check, there is no empty data, so it is complete.

# %% [markdown]
# # Fix any error identified

# %%
# Glance through the SAT 2018 values
sat_2018
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
# Glance through the ACT 2018 values
act_2018
# Out:
#                    State  Percentage of Students Tested  \
# 0                Alabama                            100
# 1                 Alaska                             33
# 2                Arizona                             66
# 3               Arkansas                            100
# 4             California                             27
# 5               Colorado                             30
# 6            Connecticut                             26
# 7               Delaware                             17
# 8   District of Columbia                             32
# 9                Florida                             66
# 10               Georgia                             53
# 11                Hawaii                             89
# 12                 Idaho                             36
# 13              Illinois                             43
# 14               Indiana                             32
# 15                  Iowa                             68
# ...

# %% [markdown]
# #Answer:
#
# There is no obvious error identified.

# %% [markdown]
# # Check the data types?

# %%
# Check the data types for SAT 2018 Data
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
# Check the data types for ACT 2017 Data
act_2018.dtypes
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
act_2018cln = pd.DataFrame(act_2018)

# %%
sat_2018cln = pd.DataFrame(sat_2018)

# %%
sat_2018cln.loc[:,'Participation'] = sat_2018.loc[:,'Participation'].apply(percentage_string_to_float)

# %%
act_2018cln.loc[:,'Percentage of Students Tested'] = act_2018.loc[:,'Percentage of Students Tested'].astype(float)

# %% [markdown]
# # Rename columns

# %%
act_2018cln.columns = act_2018cln.columns.str.lower()

# %%
sat_2018cln.columns = sat_2018cln.columns.str.lower()

# %%
#Check current columns
act_2018cln.columns
# Out:
# Index(['state', 'percentage of students tested', 'average composite score',
#        'average english score', 'average math score', 'average reading score',
#        'average science score'],
#       dtype='object')

# %%
#Check current columns
sat_2018cln.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
act_2018cln.rename(columns={
    'percentage of students tested' : 'act_participation_rate_2018',
    'average composite score' : 'act_composite_2018',
    'average english score' : 'act_english_2018',
    'average math score' : 'act_math_2018',
    'average reading score' : 'act_reading_2018',
    'average science score' : 'act_science_2018'
} , inplace=True)

# %%
sat_2018cln.rename(columns={
    'participation' : 'sat_participation_rate_2018',
    'evidence-based reading and writing' : 'sat_ebrw_2018',
    'math' : 'sat_math_2018',
    'total' : 'sat_total_2018'
} , inplace=True)

# %%
act_2018cln.head()
# Out:
#         state  act_participation_rate_2018  act_composite_2018  \
# 0     Alabama                        100.0                19.1
# 1      Alaska                         33.0                20.8
# 2     Arizona                         66.0                19.2
# 3    Arkansas                        100.0                19.4
# 4  California                         27.0                22.7
#
#    act_english_2018  act_math_2018  act_reading_2018  act_science_2018
# 0              18.9           18.3              19.6              19.0
# 1              19.8           20.6              21.6              20.7
# 2              18.2           19.4              19.5              19.2
# 3              19.1           18.9              19.7              19.4
# 4              22.5           22.5              23.0              22.1

# %%
sat_2018cln.head()
# Out:
#         state  sat_participation_rate_2018  sat_ebrw_2018  sat_math_2018  \
# 0     Alabama                          6.0            595            571
# 1      Alaska                         43.0            562            544
# 2     Arizona                         29.0            577            572
# 3    Arkansas                          5.0            592            576
# 4  California                         60.0            540            536
#
#    sat_total_2018
# 0            1166
# 1            1106
# 2            1149
# 3            1169
# 4            1076

# %% [markdown]
# # Merge Dataframes

# %%
combined_2018 = pd.merge(sat_2018cln , act_2018cln , on='state')

# %%
combined_2018.head()
# Out:
#         state  sat_participation_rate_2018  sat_ebrw_2018  sat_math_2018  \
# 0     Alabama                          6.0            595            571
# 1      Alaska                         43.0            562            544
# 2     Arizona                         29.0            577            572
# 3    Arkansas                          5.0            592            576
# 4  California                         60.0            540            536
#
#    sat_total_2018  act_participation_rate_2018  act_composite_2018  \
# 0            1166                        100.0                19.1
# 1            1106                         33.0                20.8
# 2            1149                         66.0                19.2
# 3            1169                        100.0                19.4
# 4            1076                         27.0                22.7
#
#    act_english_2018  act_math_2018  act_reading_2018  act_science_2018
# ...

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = pd.merge(combined_2017 , combined_2018 , on='state')

# %%
final.head()
# Out:
#         state  sat_participation_rate_2017  sat_ebrw_2017  sat_math_2017  \
# 0     Alabama                          5.0            593            572
# 1      Alaska                         38.0            547            533
# 2     Arizona                         30.0            563            553
# 3    Arkansas                          3.0            614            594
# 4  California                         53.0            531            524
#
#    sat_total_2017  act_participation_rate_2017  act_english_2017  \
# 0            1165                        100.0              18.9
# 1            1080                         65.0              18.7
# 2            1116                         62.0              18.6
# 3            1208                        100.0              18.9
# 4            1055                         31.0              22.5
#
#    act_math_2017  act_reading_2017  act_science_2017  ...  \
# 0           18.4              19.7              19.4  ...
# ...

# %%
final.to_csv('../data/final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
stats_describe = final.describe().transpose()
stats_describe
# Out:
#                              count         mean        std    min      25%  \
# sat_participation_rate_2017   51.0    39.803922  35.276632    2.0     4.00
# sat_ebrw_2017                 51.0   569.117647  45.666901  482.0   533.50
# sat_math_2017                 51.0   556.882353  47.121395  468.0   523.50
# sat_total_2017                51.0  1126.098039  92.494812  950.0  1055.50
# act_participation_rate_2017   51.0    65.254902  32.140842    8.0    31.00
# act_english_2017              51.0    20.931373   2.353677   16.3    19.00
# act_math_2017                 51.0    21.182353   1.981989   18.0    19.40
# act_reading_2017              51.0    22.013725   2.067271   18.1    20.45
# act_science_2017              51.0    21.041176   3.182463    2.3    19.90
# act_composite_2017            51.0    21.519608   2.020695   17.8    19.80
# sat_participation_rate_2018   51.0    45.745098  37.314256    2.0     4.50
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
def get_standard_deviation(data_list , mean):
    return (sum([(data_point - mean) ** 2 for data_point in data_list]) / len(data_list)) ** 0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Build dictionary of manually calculated standard deviations
stddev_dict = {column_name: get_standard_deviation(final.loc[:,column_name].tolist(), final.loc[:,column_name].mean()) for column_name in final.columns if column_name != 'state'}
stddev_dict_df = pd.DataFrame(stddev_dict , index=['manual_stddev']).transpose()

# %%
#Build dictionary of numpy calculated standard deviations
numpy_stddev_dict = {column_name: np.std(final.loc[:,column_name].tolist()) for column_name in final.columns if column_name != 'state'}
numpy_stddev_dict = pd.DataFrame(numpy_stddev_dict , index=['numpy_stddev']).transpose()

# %%
# merge the above 2 standard deviation dataframes with the pandas describe() dataframe for final comparison
interim = pd.merge(stats_describe.loc[:,['std']].rename(columns={'std':'pandas_stddev'}), stddev_dict_df, left_index=True, right_index=True)
pd.merge(interim, numpy_stddev_dict, left_index=True, right_index=True)
# Out:
#                              pandas_stddev  manual_stddev  numpy_stddev
# sat_participation_rate_2017      35.276632      34.929071     34.929071
# sat_ebrw_2017                    45.666901      45.216970     45.216970
# sat_math_2017                    47.121395      46.657134     46.657134
# sat_total_2017                   92.494812      91.583511     91.583511
# act_participation_rate_2017      32.140842      31.824176     31.824176
# act_english_2017                  2.353677       2.330488      2.330488
# act_math_2017                     1.981989       1.962462      1.962462
# act_reading_2017                  2.067271       2.046903      2.046903
# act_science_2017                  3.182463       3.151108      3.151108
# act_composite_2017                2.020695       2.000786      2.000786
# sat_participation_rate_2018      37.314256      36.946619     36.946619
# sat_ebrw_2018                    47.502627      47.034610     47.034610
# ...

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# By looking at the standard deviation we have calculated based on Pandas, Manual Formula & Numpy, we see that the Manual Formula is same as Numpy result.
#
# The Pandas standard deviation is slightly larger, because it used the sample standard deviation formula.

# %% [markdown]
# #### Pandas use the sample standard deviation formula
#
# $$\sigma = \sqrt{\frac{1}{n - 1}\sum_{i=1}^n(x_i - \mu)^2}$$

# %% [markdown]
# Compared to the earlier formula given, which is for population standard deviation, the difference lies in the denominator. Population standard deviation formula assumes full population size to be known at computation time, hence N is used. However, for sample standard deviation, N - 1 need to used in order for it to be an unbiased estimator of the population. Once the necessary adjustent is made to the denominator of the manual and numpy formulas, the standard deviations values would be similar to the pandas-derived values.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# # Lowest and highest participation rate for SAT in 2017 & 2018

# %%
#Lowest SAT participating states, 2017
final.sort_values('sat_participation_rate_2017')[['state','sat_participation_rate_2017']].head()
# Out:
#            state  sat_participation_rate_2017
# 34  North Dakota                          2.0
# 24   Mississippi                          2.0
# 15          Iowa                          2.0
# 25      Missouri                          3.0
# 44          Utah                          3.0

# %%
#Highest SAT participating states, 2017
final.sort_values('sat_participation_rate_2017',ascending=False)[['state','sat_participation_rate_2017']].head()
# Out:
#                    state  sat_participation_rate_2017
# 8   District of Columbia                        100.0
# 22              Michigan                        100.0
# 6            Connecticut                        100.0
# 7               Delaware                        100.0
# 29         New Hampshire                         96.0

# %% [markdown]
# Here we can see that North Dakota, Mississippi, and Iowa had the lowest participating rates in the 2017 SAT (only 2%), while District of Columbia, Michigan, Connecticut, and Delaware all had 100% participation rates.

# %%
#Lowest SAT participating states, 2018
final.sort_values('sat_participation_rate_2018')[['state','sat_participation_rate_2018']].head()
# Out:
#            state  sat_participation_rate_2018
# 34  North Dakota                          2.0
# 50       Wyoming                          3.0
# 41  South Dakota                          3.0
# 27      Nebraska                          3.0
# 49     Wisconsin                          3.0

# %%
#Highest SAT participating states, 2018
final.sort_values('sat_participation_rate_2018',ascending=False)[['state','sat_participation_rate_2018']].head(6)
# Out:
#           state  sat_participation_rate_2018
# 5      Colorado                        100.0
# 6   Connecticut                        100.0
# 7      Delaware                        100.0
# 22     Michigan                        100.0
# 12        Idaho                        100.0
# 19        Maine                         99.0

# %% [markdown]
# North Dakota again tops the list for lowest participation in the 2018 SAT (2%). Michigan, Connecticut, and Delaware all show 100% participation rates again, as well as Idaho.
#
# At a glance, it appears that the same states show similar rates year to year. It is possible that SAT is more recognized in that states.

# %% [markdown]
# # Lowest and highest ACT Participation Rates in 2017 and 2018

# %%
#Lowest ACT participating states, 2017
final.sort_values('act_participation_rate_2017')[['state','act_participation_rate_2017']].head()
# Out:
#             state  act_participation_rate_2017
# 19          Maine                          8.0
# 29  New Hampshire                         18.0
# 7        Delaware                         18.0
# 39   Rhode Island                         21.0
# 38   Pennsylvania                         23.0

# %%
#Highest ACT participating states, 2017
final.sort_values('act_participation_rate_2017',ascending=False)[['state','act_participation_rate_2017']].head(20)
# Out:
#              state  act_participation_rate_2017
# 0          Alabama                        100.0
# 17        Kentucky                        100.0
# 49       Wisconsin                        100.0
# 44            Utah                        100.0
# 42       Tennessee                        100.0
# 40  South Carolina                        100.0
# 36        Oklahoma                        100.0
# 33  North Carolina                        100.0
# 28          Nevada                        100.0
# 26         Montana                        100.0
# 24     Mississippi                        100.0
# 23       Minnesota                        100.0
# 18       Louisiana                        100.0
# 25        Missouri                        100.0
# 50         Wyoming                        100.0
# 5         Colorado                        100.0
# 3         Arkansas                        100.0
# 34    North Dakota                         98.0
# 13        Illinois                         93.0
# ...

# %% [markdown]
# The ACT seems to have a higher particpation rate across the country. Perhaps this is because ACT includes science exam while SAT does not, so more students want a test that includes the subject.

# %%
#Lowest ACT participating states, 2018
final.sort_values('act_participation_rate_2018')[['state','act_participation_rate_2018']].head()
# Out:
#             state  act_participation_rate_2018
# 19          Maine                          7.0
# 39   Rhode Island                         15.0
# 29  New Hampshire                         16.0
# 7        Delaware                         17.0
# 38   Pennsylvania                         20.0

# %%
#Highest ACT participating states, 2018
final.sort_values('act_participation_rate_2018',ascending=False)[['state','act_participation_rate_2018']].head(20)
# Out:
#              state  act_participation_rate_2018
# 0          Alabama                        100.0
# 17        Kentucky                        100.0
# 49       Wisconsin                        100.0
# 44            Utah                        100.0
# 42       Tennessee                        100.0
# 40  South Carolina                        100.0
# 36        Oklahoma                        100.0
# 35            Ohio                        100.0
# 33  North Carolina                        100.0
# 28          Nevada                        100.0
# 27        Nebraska                        100.0
# 26         Montana                        100.0
# 24     Mississippi                        100.0
# 18       Louisiana                        100.0
# 25        Missouri                        100.0
# 50         Wyoming                        100.0
# 3         Arkansas                        100.0
# 23       Minnesota                         99.0
# 34    North Dakota                         98.0
# ...

# %% [markdown]
# The ACT seems to have a higher particpation rate across the country. Perhaps this is because ACT includes science exam while SAT does not, so more students want a test that includes the subject.

# %% [markdown]
# # Lowest and highest mean total score for SAT in 2017 & 2018

# %%
#Lowest SAT Scores in 2017
final.sort_values('sat_total_2017')[['state','sat_total_2017']].head()
# Out:
#                    state  sat_total_2017
# 8   District of Columbia             950
# 7               Delaware             996
# 12                 Idaho            1005
# 22              Michigan            1005
# 19                 Maine            1012

# %%
#Lowest SAT Scores in 2018
final.sort_values('sat_total_2018')[['state','sat_total_2018']].head()
# Out:
#                    state  sat_total_2018
# 8   District of Columbia             977
# 7               Delaware             998
# 48         West Virginia             999
# 12                 Idaho            1001
# 44                  Utah            1010

# %%
#Highest SAT Scores in 2017
final.sort_values('sat_total_2017',ascending=False)[['state','sat_total_2017']].head()
# Out:
#         state  sat_total_2017
# 23  Minnesota            1295
# 49  Wisconsin            1291
# 15       Iowa            1275
# 25   Missouri            1271
# 16     Kansas            1260

# %%
#Highest SAT Scores in 2018
final.sort_values('sat_total_2018',ascending=False)[['state','sat_total_2018']].head()
# Out:
#            state  sat_total_2018
# 23     Minnesota            1298
# 49     Wisconsin            1294
# 34  North Dakota            1283
# 15          Iowa            1265
# 16        Kansas            1265

# %% [markdown]
# The four frames above show the states with the lowest mean SAT scores in 2017/18, followed by the highest.
#
# It is usually the same state that achieve the lowest/highest mean SAT scores year-by-year. It is possible that the supports given to the students in different stages are not equal. That's why students tend to perform similarly over the year.

# %% [markdown]
# # Lowest and highest mean composite score for ACT in 2017 & 2018¶

# %%
#Lowest ACT Scores in 2017
final.sort_values('act_composite_2017')[['state','act_composite_2017']].head()
# Out:
#              state  act_composite_2017
# 28          Nevada                17.8
# 24     Mississippi                18.6
# 40  South Carolina                18.7
# 11          Hawaii                19.0
# 33  North Carolina                19.1

# %%
#Lowest ACT Scores in 2018
final.sort_values('act_composite_2018')[['state','act_composite_2018']].head()
# Out:
#              state  act_composite_2018
# 28          Nevada                17.7
# 40  South Carolina                18.3
# 24     Mississippi                18.6
# 11          Hawaii                18.9
# 0          Alabama                19.1

# %%
#Highest ACT Scores in 2017
final.sort_values('act_composite_2017',ascending=False)[['state','act_composite_2017']].head()
# Out:
#                    state  act_composite_2017
# 29         New Hampshire                25.5
# 21         Massachusetts                25.4
# 6            Connecticut                25.2
# 19                 Maine                24.3
# 8   District of Columbia                24.2

# %%
#Highest ACT Scores in 2018
final.sort_values('act_composite_2018',ascending=False)[['state','act_composite_2018']].head()
# Out:
#             state  act_composite_2018
# 6     Connecticut                25.6
# 21  Massachusetts                25.5
# 29  New Hampshire                25.1
# 32       New York                24.5
# 22       Michigan                24.4

# %% [markdown]
# Similar to SAT exam, it is usually the same state that achieve the lowest/highest mean ACT composite scores year-by-year. It is possible that the supports given to the students in different stages are not equal. That's why students tend to perform similarly over the year.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
final.corr()
# Out:
#                              sat_participation_rate_2017  sat_ebrw_2017  \
# sat_participation_rate_2017                     1.000000      -0.874326
# sat_ebrw_2017                                  -0.874326       1.000000
# sat_math_2017                                  -0.855091       0.987056
# sat_total_2017                                 -0.867540       0.996661
# act_participation_rate_2017                    -0.841234       0.716153
# act_english_2017                                0.686889      -0.461345
# act_math_2017                                   0.710697      -0.486126
# act_reading_2017                                0.705352      -0.488441
# act_science_2017                                0.248553      -0.135461
# act_composite_2017                              0.694748      -0.470382
# sat_participation_rate_2018                     0.874763      -0.818925
# sat_ebrw_2018                                  -0.666313       0.814096
# ...

# %%
final_corr = final.corr()

mask = np.zeros_like(final_corr)
mask[np.tril_indices_from(mask)] = True

plt.figure(figsize=(13, 13))

sns.heatmap(final.corr() , annot = True, mask=mask)
plt.title("Correlation between all numerical values" , fontsize=28)

plt.show()

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, fig_size, list_of_xlabels, list_of_ylabels, ylimits):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=fig_size) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column], bins=11) # feel free to add more settings
        ax[i].set_title(list_of_titles[i], fontsize=18)
        ax[i].set_xlabel(list_of_xlabels[i], fontsize=8)
        ax[i].set_ylabel(list_of_ylabels[i], fontsize=8)
        ax[i].set_ylim(ylimits[i]) # otherwise it would have the .5 segments

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(final, 
                  ['sat_participation_rate_2017', 'sat_participation_rate_2018', 'act_participation_rate_2017', 'act_participation_rate_2018'], 
                  ['SAT participation rate 2017', 'SAT participation rate 2018', 'ACT participation rate 2017', 'ACT participation rate 2018'],
                  (12, 12),
                  ['Participation rate (%)', 'Participation rate (%)', 'Participation rate (%)', 'Participation rate (%)'],
                  ['State count', 'State count', 'State count', 'State count'],
                  [[0,20], [0,20], [0,20], [0,20]])

# %% [markdown]
# In these plots we can see that the distributions for SAT participation rate and ACT participation rate have not changed dramatically from 2017 to 2018. It is also clear that the SAT has a large group of very low-end participation rates (<10%), and then a group of states with 100% participation.
#
# The ACT, by contrast, has almost no states with lower than 10% participation, only a small number of states in the mid to high range, and then a large group of states with at or near 100% participation.

# %%
subplot_histograms(final, 
                  ['sat_math_2017', 'sat_math_2018', 'act_math_2017', 'act_math_2018'], 
                  ['SAT Math score 2017', 'SAT Math score 2018', 'ACT Math score 2017', 'ACT Math score 2018'],
                  (12, 12),
                  ['Score', 'Score', 'Score', 'Score'],
                  ['State count', 'State count', 'State count', 'State count'],
                  [[0,14], [0,14], [0,14], [0,14]])

# %%
subplot_histograms(final, 
                  ['sat_ebrw_2017', 'sat_ebrw_2018', 'act_reading_2017', 'act_reading_2018'], 
                  ['SAT EBRW score 2017', 'SAT EBRW score 2018', 'ACT Reading score 2017', 'ACT Reading score 2018'],
                  (12, 12),
                  ['Score', 'Score', 'Score', 'Score'],
                  ['State count', 'State count', 'State count', 'State count'],
                  [[0,14], [0,14], [0,14], [0,14]])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    sns.relplot(x=x_data, y=y_data, data=final, kind='scatter')
    plt.xlabel(x_label, fontsize=10)
    plt.ylabel(y_label, fontsize=10)
    plt.title(title, fontsize=15)
    plt.show()

# %%
scatter_plot(
    'sat_math_2017',
    'act_math_2017', 
    'SAT Math score for 2017', 
    'ACT Math score for 2017', 
    'Scatter plot of SAT vs. ACT math scores for 2017')

# %%
scatter_plot(
    'sat_ebrw_2017',
    'act_reading_2017', 
    'SAT EBRW score for 2017', 
    'ACT Reading score for 2017', 
    'Scatter plot of SAT vs. ACT verbal/reading scores for 2017')

# %%
scatter_plot(
    'sat_total_2017',
    'act_composite_2017', 
    'SAT total score for 2017)', 
    'ACT composite score for 2017', 
    'Scatter plot of SAT vs. ACT total/composite scores for 2017')

# %%
scatter_plot(
    'sat_total_2017',
    'sat_total_2018', 
    'SAT total score for 2017', 
    'SAT total score for 2018', 
    'Scatter plot of total scores for SAT 2017 vs. 2018')

# %%
scatter_plot(
    'act_composite_2017',
    'act_composite_2018', 
    'ACT composite score for 2017', 
    'ACT composite score for 2018', 
    'Scatter plot of composite scores for ACT 2017 vs. 2018')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# # ACT is more popular

# %%
#Boxplot for ACT and SAT participation rates in 2017 and 2018
participation_rates = final.loc[:,['sat_participation_rate_2017','sat_participation_rate_2018','act_participation_rate_2017','act_participation_rate_2018']]
participation_rates = participation_rates.rename(columns={
    'sat_participation_rate_2017':'SAT Participation 2017',
    'sat_participation_rate_2018':'SAT Participation 2018',
    'act_participation_rate_2017':'ACT Participation 2017',
    'act_participation_rate_2018':'ACT Participation 2018'
})
plt.figure(figsize=(10,6))
plt.title('ACT and SAT Participation Rates for 2017 vs. 2018')
sns.boxplot(data=participation_rates,palette='Set2');

# %% [markdown]
# By looking at the participation rate between SAT & ACT in this boxplot, the distribution of ACT participation rate across the 50 states is centered significantly higher than that of the SAT.

# %% [markdown]
# # Total/Composite scores for SAT/ACT in 2017 and 2018

# %%
#Boxplot for SAT total scores in 2017 and 2018
total_scores = final.loc[:,['sat_total_2017','sat_total_2018']]
total_scores = total_scores.rename(columns={
    'sat_total_2017':'SAT Total Scores 2017',
    'sat_total_2018':'SAT Total Score 2018',

})
plt.figure(figsize=(10,6))
plt.title('SAT Total Scores for 2017 vs. 2018')
sns.boxplot(data=total_scores,palette='Set2');

# %%
#Boxplot for ACT composite scores in 2017 and 2018
comp_scores = final.loc[:,['act_composite_2017','act_composite_2018']]
comp_scores = comp_scores.rename(columns={
    'act_composite_2017':'ACT Composite Scores 2017',
    'act_composite_2018':'ACT Composite Score 2018',

})
plt.figure(figsize=(10,6))
plt.title('ACT Composite Scores for 2017 vs. 2018')
sns.boxplot(data=comp_scores,palette='Set2');

# %% [markdown]
# By looking at the total/composite scores for SAT/ACT in 2017 vs. 2018, there is not much changes on the total/composite scores for the students in that 2 years.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sns.jointplot(x='sat_participation_rate_2017' , y='act_participation_rate_2017' , data=final)

# %%
sns.jointplot(x='sat_participation_rate_2018' , y='act_participation_rate_2018' , data=final)

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='sat_participation_rate_2017' , y='act_participation_rate_2017' , data=final)

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='sat_participation_rate_2018' , y='act_participation_rate_2018' , data=final)

# %% [markdown]
# There is an inverse correlation of SAT test and the ACT test. Students tend to choose 1 exam over the other.

# %%
import seaborn as sns

# %%
sns.pairplot(combined_2017)

# %%
sns.pairplot(combined_2018)

# %% [markdown]
# There seems to be some positive correlation on the subjects result, it is possible that students doing well for 1 exam, do well for other exam as well.
#
# It is possible that those students are better prepared for the ACT/SAT exam, so it is possible that they tend to do well for all the subjects together.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# SAT Participation Rate 2017

# %% [markdown]
# <img src = "../images/sat_part_2017.png">

# %% [markdown]
# SAT Participation Rate 2018

# %% [markdown]
# <img src = "../images/sat_part_2018.png">

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
sat_2017cln.describe()
# Out:
#        sat_participation_rate_2017  sat_ebrw_2017  sat_math_2017  \
# count                    51.000000      51.000000      51.000000
# mean                     39.803922     569.117647     556.882353
# std                      35.276632      45.666901      47.121395
# min                       2.000000     482.000000     468.000000
# 25%                       4.000000     533.500000     523.500000
# 50%                      38.000000     559.000000     548.000000
# 75%                      66.000000     613.000000     599.000000
# max                     100.000000     644.000000     651.000000
#
#        sat_total_2017
# count       51.000000
# mean      1126.098039
# std         92.494812
# min        950.000000
# 25%       1055.500000
# 50%       1107.000000
# 75%       1212.000000
# max       1295.000000

# %%
act_2017cln.describe()
# Out:
#        act_participation_rate_2017  act_english_2017  act_math_2017  \
# count                    52.000000         52.000000      52.000000
# mean                     65.153846         20.919231      21.173077
# std                      31.832518          2.332132       1.963602
# min                       8.000000         16.300000      18.000000
# 25%                      31.000000         19.000000      19.400000
# 50%                      68.000000         20.550000      20.900000
# 75%                     100.000000         23.300000      23.100000
# max                     100.000000         25.500000      25.300000
#
#        act_reading_2017  act_science_2017  act_composite_2017
# count         52.000000         52.000000           52.000000
# mean          22.001923         21.040385           21.509615
# std            2.048672          3.151113            2.002083
# min           18.100000          2.300000           17.800000
# ...

# %%
sat_2018cln.describe()
# Out:
#        sat_participation_rate_2018  sat_ebrw_2018  sat_math_2018  \
# count                    51.000000      51.000000      51.000000
# mean                     45.745098     563.686275     556.235294
# std                      37.314256      47.502627      47.772623
# min                       2.000000     480.000000     480.000000
# 25%                       4.500000     534.500000     522.500000
# 50%                      52.000000     552.000000     544.000000
# 75%                      77.500000     610.500000     593.500000
# max                     100.000000     643.000000     655.000000
#
#        sat_total_2018
# count       51.000000
# mean      1120.019608
# std         94.155083
# min        977.000000
# 25%       1057.500000
# 50%       1098.000000
# 75%       1204.000000
# max       1298.000000

# %%
act_2018cln.describe()
# Out:
#        act_participation_rate_2018  act_composite_2018  act_english_2018  \
# count                    51.000000           51.000000         51.000000
# mean                     61.647059           21.486275         20.988235
# std                      34.080976            2.106278          2.446356
# min                       7.000000           17.700000         16.600000
# 25%                      28.500000           19.950000         19.100000
# 50%                      66.000000           21.300000         20.200000
# 75%                     100.000000           23.550000         23.700000
# max                     100.000000           25.600000         26.000000
#
#        act_math_2018  act_reading_2018  act_science_2018
# count      51.000000         51.000000         51.000000
# mean       21.125490         22.015686         21.345098
# std         2.035765          2.167245          1.870114
# min        17.800000         18.000000         17.900000
# ...

# %% [markdown]
# For SAT, the mean total score is 1,126 in 2017 & 1,120 in 2018. The standard deviation is 92.5 in 2017 & 94.2 in 2018. There is not much difference in the SAT mean total score in the 2 years.
#
# For ACT, the mean composite score is 21.5 in 2017 & 21.3 in 2018. The standard deviation is 2 in 2017 & 1.9 in 2018. There is also not much difference in the SAT mean total score in the 2 years.

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# Answer:

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# # Drawing histogram on the test scores for SAT/ACT subjects in 2017 & 2018

# %%
# Checking the SAT math result in 2017
plt.hist(final.sat_math_2017,bins = 20);

# %%
# Checking the SAT math result in 2018
plt.hist(final.sat_math_2018,bins = 20);

# %%
# Checking the ACT math result in 2017
plt.hist(final.act_math_2017,bins = 20);

# %%
# Checking the ACT math result in 2018
plt.hist(final.act_math_2018,bins = 20);

# %% [markdown]
# By looking at the histogram of the Math test scores for SAT/ACT in 2017 & 2018, it does not really show a normal distribution.

# %%
# Checking the SAT ebrw result in 2017
plt.hist(final.sat_ebrw_2017,bins = 20);

# %%
# Checking the SAT ebrw result in 2018
plt.hist(final.sat_ebrw_2017,bins = 20);

# %%
# Checking the ACT reading result in 2017
plt.hist(final.act_reading_2017,bins = 20);

# %%
# Checking the ACT reading result in 2018
plt.hist(final.act_reading_2018,bins = 20);

# %% [markdown]
# By looking at the histogram of the Reading test scores for SAT/ACT in 2017 & 2018, it does not really show a normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:
#
# By looking at the correlation plot, SAT & ACT participation rates seem to be inversely-correlated. Students taking one exam is less likely to take another exam.
#
# Therefore, it does not make sense to conduct statistical inference based on these 2 particpation rates.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# Answer:
#
# By looking at the correlation values, there seem to be no signifant correlation between the SAT and ACT math scores, so the math result of these 2 tests seem to be independent.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %% [markdown]
# # Doing t-test to find if there is any significant difference in the mean participation rate of SAT/ACT in 2017 vs 2018

# %%
from scipy import stats

# %%
# Checking the SAT participation rate
x = final.sat_participation_rate_2018

# %%
y = final.sat_participation_rate_2017

# %%
stats.ttest_ind(x , y , equal_var=False)
# Out:
# Ttest_indResult(statistic=0.8262650776952394, pvalue=0.41062697785955005)

# %%
t1_stat, p1_value = stats.ttest_ind(x , y , equal_var=False)

# %%
t1_stat
# Out:
# 0.8262650776952394

# %%
# Checking the ACT result
a = final.act_participation_rate_2018

# %%
b = final.act_participation_rate_2017

# %%
stats.ttest_ind(a , b , equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.5499970052081788, pvalue=0.5835519913078026)

# %%
t2_stat, p2_value = stats.ttest_ind(a , b , equal_var=False)

# %%
t2_stat
# Out:
# -0.5499970052081788

# %% [markdown]
# Based on the t-test, there is no statistically significant difference in the mean of SAT/ACT result between 2018 & 2019.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# https://www.edweek.org/ew/section/multimedia/states-require-students-take-sat-or-act.html
#
# Based on outside research, there are different requirements for students to take SAT or ACT exams. The following states require students to take SAT exam:
#
# 1) Colorado
# 2) Connecticut
# 3) Delware
# 4) District of Columbia
# 5) Idaho
# 6) Illinois
# 7) Maine
# 8) Michigan
# 9) New Hampshire
# 10) Ohio
# 11) Oklahoma
# 12) Rhode Island
# 13) Tennessee
# 14) West Virginia
#
# Similarly, the following states require students to take ACT exam:
#
# 1) Alabama
# 2) Arkansas
# 3) Hawaii
# 4) Idaho
# 5) Kentuchy
# 6) Michigan
# 7) Mississippi
# 8) Montana
# 9) Nebraska
# 10) Nevada
# 11) North Carolina
# 12) Ohio
# 13) Okiahoma
# 14) Tennessee
# 15) Utah
# 16) Wisconsin
# 17) Wyoming

# %% [markdown]
# SAT predominant states in blue, ACT predominant states in red.

# %% [markdown]
# <img src = "../images/sat_vs_act.png">

# %% [markdown]
# As different states have different requirements, that's the reason why SAT is more popular in certain states while ACT is more popular in others.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# The ACT and SAT particpation distributions are inversely correlated to each other, with states tending to prefer one test or the other. There are strong regional affiliations associated with ACT vs. SAT preference. Coastal progressive states tend to favor the SAT, while the central regions tend to favor the ACT. Currently, more than 50% of the states require high school students take either the SAT or ACT.
#
# To increase participation, states which have not already done so can consider making one of the two exam a mandatory high school graduation requirement. Having completed the requirement and knowing their score can be useful in directing students to consider appropriate school.
#
# Further research into other influential factors, particularly into the benefits to students of taking the SAT or ACT exam, will be helpful to developing a strategy for increasing participation.
