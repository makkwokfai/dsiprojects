# %% [markdown]
# # DSI 18 - Capstone Project
#
# # Households Electricity Consumption Prediction 2021

# %% [markdown]
# ## Contents
#
# - [1. Objective](#1.-Objective)
#     - [1.1. Problem Statement](#1.1.-Problem-Statement)
#     - [1.2. Data Sources](#1.2.-Data-Sources)
#     - [1.3. Approaches](#1.3.-Approaches)
# - [2. Check the data given](#2.-Check-the-data-given)
#     - [2.1. Definition of sunshine hours](#2.1.-Definition-of-sunshine-hours)
# - [3. Clean the data](#3.-Clean-the-data)
#     - [3.1. Clean the data](#3.1.-Clean-the-data)
#     - [3.2. Combine the data](#3.2.-Combine-the-data)
# - [4. EDA](#4.-EDA)
#     - [4.1. Correlation of sunshine](#4.1.-Correlation-of-sunshine)
#     - [4.2. Analyze different type of properties](#4.2.-Analyze-different-type-of-properties)
#     - [4.3. Analyze changes in mean sunshine hours for different years](#4.3.-Analyze-changes-in-mean-sunshine-hours-for-different-years)
# - [5. Autocorrelation](#5.-Autocorrelation)
#     - [5.1. Autocorrelation for 1 room & 2 room data](#5.1.-Autocorrelation-for-1-room-&-2-room-data)
#     - [5.2. Autocorrelation for 3 room data](#5.2.-Autocorrelation-for-3-room-data)
#     - [5.3. Autocorrelation for 4 room data](#5.3.-Autocorrelation-for-4-room-data)
#     - [5.4. Autocorrelation for 5 room & executive data](#5.4.-Autocorrelation-for-5-room-&-executive-data)
#     - [5.5. Autocorrelation for private apartments & condo data](#5.5.-Autocorrelation-for-private-apartments-&-condo-data)
#     - [5.6. Autocorrelation for landed properties data](#5.6.-Autocorrelation-for-landed-properties-data)
#     - [5.7. Autocorrelation for others](#5.7.-Autocorrelation-for-others)
# - [6. Train/Test split](#6.-Train/Test-split)
#     - [6.1. Train/Test split for 1 room & 2 room data](#6.1.-Train/Test-split-for-1-room-&-2-room-data)
#     - [6.2. Train/Test split for 3 room data](#6.2.-Train/Test-split-for-3-room-data)
#     - [6.3. Train/Test split for 4 room data](#6.3.-Train/Test-split-for-4-room-data)
#     - [6.4. Train/Test split for 5 room & executive data](#6.4.-Train/Test-split-for-5-room-&-executive-data)
#     - [6.5. Train/Test split for private apartments & condo data](#6.5.-Train/Test-split-for-private-apartments-&-condo-data)
#     - [6.6. Train/Test split for landed properties data](#6.6.-Train/Test-split-for-landed-properties-data)
#     - [6.7. Train/Test split for others](#6.7.-Train/Test-split-for-others)
# - [7. Plotting ACF and PACF](#7.-Plotting-ACF-and-PACF)
#     - [7.1. ACF & PACF for 1 room & 2 room data](#7.1.-ACF-&-PACF-for-1-room-&-2-room-data)
#     - [7.2. ACF & PACF for 3 room data](#7.2.-ACF-&-PACF-for-3-room-data)
#     - [7.3. ACF & PACF for 4 room data](#7.3.-ACF-&-PACF-for-4-room-data)
#     - [7.4. ACF & PACF for 5 room & executive data](#7.4.-ACF-&-PACF-for-5-room-&-executive-data)
#     - [7.5. ACF & PACF for private apartments & condo data](#7.5.-ACF-&-PACF-for-private-apartments-&-condo-data)
#     - [7.6. ACF & PACF for landed properties data](#7.6.-ACF-&-PACF-for-landed-properties-data)
#     - [7.7. ACF & PACF for others](#7.7.-ACF-&-PACF-for-others)
# - [8. Apply Dickey Fuller test](#8.-Apply-Dickey-Fuller-test)
#     - [8.1. Dickey Fuller test for 1 room & 2 room data](#8.1.-Dickey-Fuller-test-for-1-room-&-2-room-data)
#     - [8.2. Dickey Fuller test for 3 room data](#8.2.-Dickey-Fuller-test-for-3-room-data)
#     - [8.3. Dickey Fuller test for 4 room data](#8.3.-Dickey-Fuller-test-for-4-room-data)
#     - [8.4. Dickey Fuller test for 5 room & executive data](#8.4.-Dickey-Fuller-test-for-5-room-&-executive-data)
#     - [8.5. Dickey Fuller test for private apartments & condo data](#8.5.-Dickey-Fuller-test-for-private-apartments-&-condo-data)
#     - [8.6. Dickey Fuller test for landed properties data](#8.6.-Dickey-Fuller-test-for-landed-properties-data)
#     - [8.7. Dickey Fuller test for others](#8.7.-Dickey-Fuller-test-for-others)
# - [9. Conclusions and Recommendations](#9.-Conclusions-and-Recommendations)
# - [10. References](#10.-References)
# - [11. QUESTIONS ???](#11.-QUESTIONS-???)

# %% [markdown]
# ## 1. Objective
# [top](#Contents)

# %% [markdown]
# ###### Based on the households electricity consumption in Singapore in 2005 - 2020, we are going to predict the households electricity consumption in Singapore for 2021.

# %% [markdown]
# ### 1.1. Problem Statement
# [top](#Contents)

# %% [markdown]
# ... to be continued ...

# %% [markdown]
# ### 1.2. Data Sources
# [top](#Contents)

# %% [markdown]
# Past year Energy Consumption in Singapore from 2005 to 2020:
#
# https://www.kaggle.com/zyc191/energy-consumption-singapore-from-opendata

# %% [markdown]
# ### 1.3. Approaches
# [top](#Contents)

# %% [markdown]
# ... to be continued ...

# %% [markdown]
# ## 2. Check the data given
# [top](#Contents)

# %% [markdown]
# **2 set** of datas are given by Kaggle, we will browse through it one-by-one.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
sunshine = pd.read_csv('../datasets/sunshine_duration_monthly_mean_daily_duration.csv')
sunshine.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
sunshine.tail()
# Out:
#        month  mean_sunshine_hrs
# 461  2020-06                4.3
# 462  2020-07                5.7
# 463  2020-08                6.4
# 464  2020-09                4.8
# 465  2020-10                4.3

# %%
sunshine.describe()
# Out:
#        mean_sunshine_hrs
# count         466.000000
# mean            5.674464
# std             1.207740
# min             2.700000
# 25%             4.800000
# 50%             5.600000
# 75%             6.400000
# max             9.300000

# %%
household = pd.read_csv('../datasets/total_household_electricity_consumption_2005_2020.csv')
household.head()
# Out:
#      month  overall  public_housing  1-room_2-room  3-room  4-room  \
# 0  2019-01    594.1           343.4           11.5    61.1   143.3
# 1  2019-02    613.6           356.0           11.7    62.3   148.5
# 2  2019-03    598.2           340.9           11.2    59.6   142.0
# 3  2019-04    653.1           374.6           12.3    66.2   155.9
# 4  2019-05    670.5           385.9           12.8    68.3   160.7
#
#    5-room_and_executive  private_housing  private_apts_and_condo  \
# 0                 127.4            249.8                   163.0
# 1                 133.4            256.7                   167.6
# 2                 128.0            256.5                   167.8
# 3                 140.2            277.6                   183.6
# 4                 144.0            283.7                   190.0
#
#    landed_properties  others
# 0               86.9     0.8
# 1               89.1     0.8
# 2               88.7     0.8
# 3               94.0     0.9
# ...

# %%
household.tail()
# Out:
#        month  overall  public_housing  1-room_2-room  3-room  4-room  \
# 182  2020-03    620.6           354.6           12.3    62.0   148.2
# 183  2020-04    669.9           383.4           13.3    66.8   160.6
# 184  2020-05    663.3           381.9           13.7    67.4   160.2
# 185  2020-06    869.7           501.6           17.3    86.8   209.3
# 186  2020-07    886.7           515.2           18.1    87.1   215.2
#
#      5-room_and_executive  private_housing  private_apts_and_condo  \
# 182                 132.1            265.2                   175.3
# 183                 142.6            285.7                   187.7
# 184                 140.6            280.5                   183.9
# 185                 188.2            367.0                   253.3
# 186                 194.8            370.6                   259.6
#
#      landed_properties  others
# 182               90.0     0.8
# 183               97.9     0.9
# 184               96.6     1.0
# ...

# %%
household.describe()
# Out:
#           overall  public_housing  1-room_2-room      3-room      4-room  \
# count  187.000000      187.000000     187.000000  187.000000  187.000000
# mean   568.124599      339.652406       8.560963   61.706417  137.516043
# std     69.077311       36.751159       2.528212    5.810970   16.690254
# min    437.100000      270.800000       5.300000   50.400000  107.100000
# 25%    518.850000      314.550000       6.400000   57.900000  126.400000
# 50%    563.500000      337.800000       7.600000   61.500000  136.400000
# 75%    612.550000      363.850000      10.700000   65.350000  148.350000
# max    886.700000      515.200000      18.100000   87.100000  215.200000
#
#        5-room_and_executive  private_housing  private_apts_and_condo  \
# count            187.000000       187.000000              187.000000
# mean             131.865775       227.499465              142.231016
# std               12.778081        33.238376               26.868469
# ...

# %% [markdown]
# #### Interpretation:
#
# We want to predict the household energy consumption in 2021, it is necessary to do it base on past years result. I intend to break-it down and check the energy consumption for different types of household seperatly, and forecast the future consumption.
#
# These are the data we are using:
#
# |Data Given|Duration|Frequency|
# |---|---|---|
# |Mean daily sunshine|Jan 1982 - Oct 2020|Monthly|
# |Household electricity consumption|Jan 2005 - Jul 2020|Monthly|
#
# The mean daily sunshine has an average of 5.6 hours and a standard deviation of 1.2 hours. For electricity consumption, it varies for different type of properties, with average values 8.6 - 142 KWh, and a standard deviation of 2.5 - 26.9 KWh.

# %% [markdown]
# ### 2.1. Definition of sunshine hours
# [top](#Contents)

# %% [markdown]
# Given the theoretical maximum of daytime duration for a given location, there is also a practical consideration at which point the amount of daylight is sufficient to be treated as a "sunshine hour". "Bright" sunshine hours represent the total hours when the sunlight is stronger than a specified threshold, as opposed to just "visible" hours. "Visible" sunshine, for example, occurs around sunrise and sunset, but is not strong enough to excite the sensor.

# %% [markdown]
# <img src = "../image/Sunshine.PNG">

# %% [markdown]
# According to Wikipedia, Singapore has a sunshine duration of about 129.2 - 192.7 hours per month. It is a general indicator of cloudines of a location. It is equivalent to 4.3 - 6.4 hours per day, which match the result in the `total_household_electricity_consumption_2005_2020.csv` data.

# %% [markdown]
# ## 3. Clean the data
# [top](#Contents)

# %% [markdown]
# ### 3.1. Clean the data
# [top](#Contents)

# %% [markdown]
# We will first check the duration of the data given.

# %% [markdown]
# #### 1. `sunshine` data.

# %%
sunshine['month'].unique()
# Out:
# array(['1982-01', '1982-02', '1982-03', '1982-04', '1982-05', '1982-06',
#        '1982-07', '1982-08', '1982-09', '1982-10', '1982-11', '1982-12',
#        '1983-01', '1983-02', '1983-03', '1983-04', '1983-05', '1983-06',
#        '1983-07', '1983-08', '1983-09', '1983-10', '1983-11', '1983-12',
#        '1984-01', '1984-02', '1984-03', '1984-04', '1984-05', '1984-06',
#        '1984-07', '1984-08', '1984-09', '1984-10', '1984-11', '1984-12',
#        '1985-01', '1985-02', '1985-03', '1985-04', '1985-05', '1985-06',
#        '1985-07', '1985-08', '1985-09', '1985-10', '1985-11', '1985-12',
#        '1986-01', '1986-02', '1986-03', '1986-04', '1986-05', '1986-06',
#        '1986-07', '1986-08', '1986-09', '1986-10', '1986-11', '1986-12',
#        '1987-01', '1987-02', '1987-03', '1987-04', '1987-05', '1987-06',
#        '1987-07', '1987-08', '1987-09', '1987-10', '1987-11', '1987-12',
#        '1988-01', '1988-02', '1988-03', '1988-04', '1988-05', '1988-06',
# ...

# %% [markdown]
# For sunshine data, we are given from 1982-01 to 2020-10, all in order. Since we only have household data from 2005 onwards, and we do not have full year data for 2020, so we will extract only data from 2005-01 to 2019-12.

# %%
# Extract result from 2005-01 to 2019-12
sunshine_extract = sunshine[(sunshine['month'] > '2004-12') & (sunshine['month'] < '2020-01')]
sunshine_extract.head()
# Out:
#        month  mean_sunshine_hrs
# 276  2005-01                6.5
# 277  2005-02                9.1
# 278  2005-03                7.2
# 279  2005-04                7.0
# 280  2005-05                5.5

# %%
# Set the month as index
sunshine_extract.set_index('month', inplace=True)
sunshine_extract.head()
# Out:
#          mean_sunshine_hrs
# month
# 2005-01                6.5
# 2005-02                9.1
# 2005-03                7.2
# 2005-04                7.0
# 2005-05                5.5

# %% [markdown]
# #### 2. `household` data.

# %%
household['month'].unique()
# Out:
# array(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06',
#        '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12',
#        '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06',
#        '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12',
#        '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06',
#        '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12',
#        '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
# ...

# %% [markdown]
# For household data, we are given data from 2005-01 to 2020-06, not in order. We will sort the data first, since we do not have full year data for 2020, so we will extract only data from 2005-01 to 2019-12.

# %%
# Sort the result
household  = household.sort_values('month')
household = household.reset_index(drop=True)

# %%
# Extract restult till 2019-12
household_extract = household[(household['month'] < '2020-01')]
household_extract.head()
# Out:
#      month  overall  public_housing  1-room_2-room  3-room  4-room  \
# 0  2005-01    447.8           280.7            6.3    52.9   111.1
# 1  2005-02    437.1           270.8            6.0    51.5   107.3
# 2  2005-03    479.7           295.4            6.1    55.4   117.1
# 3  2005-04    533.6           331.6            6.9    61.4   131.5
# 4  2005-05    535.0           330.5            6.8    61.5   130.9
#
#    5-room_and_executive  private_housing  private_apts_and_condo  \
# 0                 110.4            166.2                    95.8
# 1                 106.0            165.5                    94.8
# 2                 116.8            183.3                   104.8
# 3                 131.8            200.9                   117.9
# 4                 131.2            203.5                   120.4
#
#    landed_properties  others
# 0               70.4     0.9
# 1               70.7     0.9
# 2               78.5     1.0
# 3               83.1     1.1
# ...

# %%
# Set the month as index
household_extract.set_index('month', inplace=True)
household_extract.head()
# Out:
#          overall  public_housing  1-room_2-room  3-room  4-room  \
# month
# 2005-01    447.8           280.7            6.3    52.9   111.1
# 2005-02    437.1           270.8            6.0    51.5   107.3
# 2005-03    479.7           295.4            6.1    55.4   117.1
# 2005-04    533.6           331.6            6.9    61.4   131.5
# 2005-05    535.0           330.5            6.8    61.5   130.9
#
#          5-room_and_executive  private_housing  private_apts_and_condo  \
# month
# 2005-01                 110.4            166.2                    95.8
# 2005-02                 106.0            165.5                    94.8
# 2005-03                 116.8            183.3                   104.8
# 2005-04                 131.8            200.9                   117.9
# 2005-05                 131.2            203.5                   120.4
#
#          landed_properties  others
# month
# 2005-01               70.4     0.9
# 2005-02               70.7     0.9
# ...

# %% [markdown]
# ### 3.2. Combine the data
# [top](#Contents)

# %%
energy_final = pd.concat([sunshine_extract , household_extract] , axis=1)

# %%
energy_final.head()
# Out:
#          mean_sunshine_hrs  overall  public_housing  1-room_2-room  3-room  \
# month
# 2005-01                6.5    447.8           280.7            6.3    52.9
# 2005-02                9.1    437.1           270.8            6.0    51.5
# 2005-03                7.2    479.7           295.4            6.1    55.4
# 2005-04                7.0    533.6           331.6            6.9    61.4
# 2005-05                5.5    535.0           330.5            6.8    61.5
#
#          4-room  5-room_and_executive  private_housing  \
# month
# 2005-01   111.1                 110.4            166.2
# 2005-02   107.3                 106.0            165.5
# 2005-03   117.1                 116.8            183.3
# 2005-04   131.5                 131.8            200.9
# 2005-05   130.9                 131.2            203.5
#
#          private_apts_and_condo  landed_properties  others
# month
# 2005-01                    95.8               70.4     0.9
# ...

# %%
energy_final.shape
# Out:
# (180, 11)

# %% [markdown]
# ## 4. EDA
# [top](#Contents)

# %% [markdown]
# ### 4.1. Correlation of sunshine
# [top](#Contents)

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(energy_final.corr() , cmap='icefire',mask=np.triu(energy_final.corr()),annot=True)
# Out:
# <AxesSubplot:>

# %%
sunshine = energy_final.corr()[['mean_sunshine_hrs']]

# %%
sunshine.sort_values(by='mean_sunshine_hrs')
# Out:
#                         mean_sunshine_hrs
# others                          -0.206153
# 5-room_and_executive            -0.081755
# 3-room                          -0.052087
# public_housing                  -0.025501
# overall                          0.004434
# 4-room                           0.006496
# landed_properties                0.012155
# private_housing                  0.037900
# private_apts_and_condo           0.043624
# 1-room_2-room                    0.120223
# mean_sunshine_hrs                1.000000

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))

# Create scatter plot of high prices versus volume.
plt.scatter(energy_final['mean_sunshine_hrs'],
            energy_final['1-room_2-room']);

plt.title("Mean Sunshine Hours versus Energy Consumption for 1-Room & 2-Room HDB" , fontsize=20)
plt.ylabel("Energy Consumption for 1-Room & 2-Room HDB", fontsize = 12)
plt.xlabel("Mean Sunshine Hours", fontsize = 12);

# %% [markdown]
# #### Interpretation:
#
# There is not much correlation between the mean sunshine hours to energy consumption.
#
# Before doing the correlation plot, i was thinking Energy Consumption should have a negative correlation with Sunshine Hours, as longer the sunlight should mean residents have a shorter duration on the electrical light. However, when i plot the correlation all the data, the result is different from my expectation, as there is not much correlation from mean sunshine hours to electricity consumption.
#
# I think that's because of the data we used, as we capture the "bright" sunshine hours for each day. "Bright" sunshine hours represent the total hours when the sunlight is stronger than a specified threshold, as opposed to just "visible" hours. "Visible" sunshine, for example, occurs around sunrise and sunset, but is not strong enough to excite the sensor. My expectation should apply only for "visible" sunshine, but not for this case.

# %% [markdown]
# ### 4.2. Analyze different type of properties
# [top](#Contents)

# %% [markdown]
# For energy consumption of households, it can be further seperated into different residential types:
#
# - Public Housing
#         1. 1-room_2-room
#         2. 3-room
#         3. 4-room
#         4. 5-room_and_executive
# - Private Housing
#         1. private_apts_and_condo
#         2. landed_properties
# - others
#
# We will look at the energy comsumpted by each residential types one-by-one.

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['1-room_2-room'])
plt.title('Plot of Electricity Consumption in 1 Room & 2 Room' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['3-room'])
plt.title('Plot of Electricity Consumption in 3 Room' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['4-room'])
plt.title('Plot of Electricity Consumption in 4 Room' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['5-room_and_executive'])
plt.title('Plot of Electricity Consumption in 5 room & executive' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['private_apts_and_condo'])
plt.title('Plot of Electricity Consumption in private apartments & condo' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['landed_properties'])
plt.title('Plot of Electricity Consumption in landed properties' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['others'])
plt.title('Plot of Electricity Consumption in others' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %% [markdown]
# #### Interpretation:
#
# We see that the electricity consumption for different types of properties increase over the years.

# %% [markdown]
# ### 4.3. Analyze changes in mean sunshine hours for different years
# [top](#Contents)

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['mean_sunshine_hrs'])
plt.title('Plot of Mean Sunshine hours over the year' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Mean Sunshine Hours',fontsize=18)
# Out:
# Text(0, 0.5, 'Mean Sunshine Hours')

# %% [markdown]
# #### Interpretation:
#
# The mean sunshine are between 3 - 9 hours, there is no significant changes in the number of hours over the year. We usually observe a longer sunshine in January, and shorter sunshine in November.

# %% [markdown]
# ## 5. Autocorrelation
# [top](#Contents)

# %% [markdown]
# By looking at the households electricity consumption, it seems like that the result is cyclical. We will look at 3 lags interval:
# - 3 months
# - 6 months
# - 1 year (12 months)

# %% [markdown]
# ### 5.1. Autocorrelation for 1 room & 2 room data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["1-room_2-room"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["1-room_2-room"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["1-room_2-room"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.9408
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.9134
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.973

# %% [markdown]
# ### 5.2. Autocorrelation for 3 room data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["3-room"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["3-room"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["3-room"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.1916
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: -0.1596
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.7968

# %% [markdown]
# ### 5.3. Autocorrelation for 4 room data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["4-room"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["4-room"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["4-room"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.4703
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.2247
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.8673

# %% [markdown]
# ### 5.4. Autocorrelation for 5 room & executive data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["5-room_and_executive"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["5-room_and_executive"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["5-room_and_executive"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.1222
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: -0.2756
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.7875

# %% [markdown]
# ### 5.5. Autocorrelation for private apartments & condo data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["private_apts_and_condo"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["private_apts_and_condo"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["private_apts_and_condo"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.719
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.6527
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.9242

# %% [markdown]
# ### 5.6. Autocorrelation for landed properties data
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["landed_properties"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["landed_properties"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["landed_properties"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.2566
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.0328
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.7154

# %% [markdown]
# ### 5.7. Autocorrelation for others
# [top](#Contents)

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.565
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.5919
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.8197

# %% [markdown]
# #### Interpretation:
#
# By looking at the 3 lags interval we have selected: 3-months, 6-months & 12-months, the 12-months (1 year) lag of electricity consumption is strongly correlated with the current electricity consumption. This would suggest that there might be a seasonal influence working on electricity consumption separated by one year.

# %% [markdown]
# $$
# \begin{eqnarray*}
#     Y_t &=& \mu + \beta(Y_{t-12}) + \varepsilon_t \\
# \end{eqnarray*}
# $$

# %% [markdown]
# ## 6. Train/Test split
# [top](#Contents)

# %% [markdown]
# Modeling with time series data presents unique challenges because our observations are not independent of one another.
#
# So, in splitting the data into `train` and `test` sets, **we cannot split randomly**. Use the first *75%* of observations as training data and the following 25% for test data.

# %%
print(f'Number of years in the observations: {len(energy_final)/12}')
print(f'Number of years in the training observations: {round(len(energy_final)/12 * 0.75)}')
print(f'Number of years in the testing observations: {len(energy_final)/12 - round(len(energy_final)/12 * 0.75)}')
# Out:
# Number of years in the observations: 15.0
# Number of years in the training observations: 11
# Number of years in the testing observations: 4.0

# %% [markdown]
# Therefore, we set the first 11 years (2005 - 2015) of the observation as our train data, and last 4 years (2016 - 2019) of our observation as our test data.

# %%
11 * 12
# Out:
# 132

# %%
energy_final.iloc[131:133]
# Out:
#          mean_sunshine_hrs  overall  public_housing  1-room_2-room  3-room  \
# month
# 2015-12                5.3    622.4           370.3           10.7    66.0
# 2016-01                7.2    570.2           336.7           10.2    61.2
#
#          4-room  5-room_and_executive  private_housing  \
# month
# 2015-12   151.9                 141.7            251.2
# 2016-01   137.9                 127.4            232.7
#
#          private_apts_and_condo  landed_properties  others
# month
# 2015-12                   160.5               90.7     0.9
# 2016-01                   148.4               84.3     0.9

# %%
def train_test_plot(train, test):
    plt.figure(figsize=(30, 12))
    plt.plot(train, c='blue')
    plt.plot(test, c='orange');
    plt.xlabel('Time',fontsize=18)
    plt.xticks(rotation=90, fontsize=6)
    plt.ylabel('Electricity Consumption in KWh',fontsize=18)

# %% [markdown]
# ### 6.1. Train/Test split for 1 room & 2 room data
# [top](#Contents)

# %%
train_1room_2room = energy_final['1-room_2-room'].iloc[:132,]
test_1room_2room = energy_final['1-room_2-room'].iloc[132:,]

# %%
train_test_plot(train_1room_2room , test_1room_2room)

# %% [markdown]
# ### 6.2. Train/Test split for 3 room data
# [top](#Contents)

# %%
train_3room = energy_final['3-room'].iloc[:132,]
test_3room = energy_final['3-room'].iloc[132:,]

# %%
train_test_plot(train_3room , test_3room)

# %% [markdown]
# ### 6.3. Train/Test split for 4 room data
# [top](#Contents)

# %%
train_4room = energy_final['4-room'].iloc[:132,]
test_4room = energy_final['4-room'].iloc[132:,]

# %%
train_test_plot(train_4room , test_4room)

# %% [markdown]
# ### 6.4. Train/Test split for 5 room & executive data
# [top](#Contents)

# %%
train_5room_exe = energy_final['5-room_and_executive'].iloc[:132,]
test_5room_exe = energy_final['5-room_and_executive'].iloc[132:,]

# %%
train_test_plot(train_5room_exe , test_5room_exe)

# %% [markdown]
# ### 6.5. Train/Test split for private apartments & condo data
# [top](#Contents)

# %%
train_pte_apts_condo = energy_final['private_apts_and_condo'].iloc[:132,]
test_pte_apts_condo = energy_final['private_apts_and_condo'].iloc[132:,]

# %%
train_test_plot(train_pte_apts_condo , test_pte_apts_condo)

# %% [markdown]
# ### 6.6. Train/Test split for landed properties data
# [top](#Contents)

# %%
train_landed_pty = energy_final['landed_properties'].iloc[:132,]
test_landed_pty = energy_final['landed_properties'].iloc[132:,]

# %%
train_test_plot(train_landed_pty , test_landed_pty)

# %% [markdown]
# ### 6.7. Train/Test split for others
# [top](#Contents)

# %%
train_others = energy_final['others'].iloc[:132,]
test_others = energy_final['others'].iloc[132:,]

# %%
train_test_plot(train_others , test_others)

# %% [markdown]
# ## 7. Plotting ACF and PACF
# [top](#Contents)

# %% [markdown]
# From the autocorrelation result, the 12-months lag of electricity consumption is strongly correlated with the current month's electricity consumption. This would suggest that there may be seasonal influence working on electricity consumption seperated by one year.
#
# We will plot the 12-months `ACF` and 12-months `PACF` plot now.

# %% [markdown]
# ### 7.1. ACF & PACF for 1 room & 2 room data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_1room_2room, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_1room_2room, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> What model? </font>

# %% [markdown]
# ### 7.2. ACF & PACF for 3 room data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_3room, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_3room, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (4, 4)? </font>

# %% [markdown]
# ### 7.3. ACF & PACF for 4 room data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_4room, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_4room, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (4, 4)? </font>

# %% [markdown]
# ### 7.4. ACF & PACF for 5 room & executive data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_5room_exe, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_5room_exe, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (4, 5)? </font>

# %% [markdown]
# ### 7.5. ACF & PACF for private apartments & condo data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_pte_apts_condo, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_pte_apts_condo, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (6, 5)? </font>

# %% [markdown]
# ### 7.6. ACF & PACF for landed properties data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_landed_pty, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_landed_pty, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (4, 4)? </font>

# %% [markdown]
# ### 7.7. ACF & PACF for others
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_others, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_others, lags = 12);

# %% [markdown]
# > <font size = 3 color = "crimson"> Is it ARMA (4, 3)? </font>

# %% [markdown]
# ## 8. Apply Dickey Fuller test
# [top](#Contents)

# %% [markdown]
# Dickey Fuller test is used to determine whether or not the data are stationary.

# %%
# Import Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller

# Define function to easily interpret results.
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %% [markdown]
# ### 8.1. Dickey Fuller test for 1 room & 2 room data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_1room_2room))
# Out:
# Test Statistic    2.566639
# p-value           0.999068
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# NOT STATIONARY

# %% [markdown]
# ### 8.2. Dickey Fuller test for 3 room data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_3room))
# Out:
# Test Statistic    0.261014
# p-value           0.975483
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is more than our reasonable choices for  𝛼 , we do not have enough evidence to reject the null hypothesis and conclude that our time series is not stationary.

# %% [markdown]
# ### 8.3. Dickey Fuller test for 4 room data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_4room))
# Out:
# Test Statistic    1.444071
# p-value           0.997305
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is less than our reasonable choices for  𝛼 , we have enough evidence to reject the null hypothesis and we accept that our time series is stationary.

# %% [markdown]
# ### 8.4. Dickey Fuller test for 5 room & executive data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_5room_exe))
# Out:
# Test Statistic   -0.076302
# p-value           0.951748
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is more than our reasonable choices for  𝛼 , we do not have enough evidence to reject the null hypothesis and conclude that our time series is not stationary.

# %% [markdown]
# ### 8.5. Dickey Fuller test for private apartments & condo data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_pte_apts_condo))
# Out:
# Test Statistic    1.284431
# p-value           0.996520
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is less than our reasonable choices for  𝛼 , we have enough evidence to reject the null hypothesis and we accept that our time series is stationary.

# %% [markdown]
# ### 8.6. Dickey Fuller test for landed properties data
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_landed_pty))
# Out:
# Test Statistic   -0.212708
# p-value           0.936990
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is more than our reasonable choices for  𝛼 , we do not have enough evidence to reject the null hypothesis and conclude that our time series is not stationary.

# %% [markdown]
# ### 8.7. Dickey Fuller test for others
# [top](#Contents)

# %%
# Execute test on training data.
interpret_dftest(adfuller(train_others))
# Out:
# Test Statistic    0.340965
# p-value           0.979148
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# Because  𝑝  is more than our reasonable choices for  𝛼 , we do not have enough evidence to reject the null hypothesis and conclude that our time series is not stationary.

# %% [markdown]
# ## 9. Conclusions and Recommendations
# [top](#Contents)

# %% [markdown]
# ... to be continued ...

# %% [markdown]
# ## 10. References
# [top](#Contents)

# %% [markdown]
# [1] Sunshine duration. https://en.wikipedia.org/wiki/Sunshine_duration
#
# [2] List of cities by sunshine duration https://en.wikipedia.org/wiki/List_of_cities_by_sunshine_duration

# %% [markdown]
# ## 11. QUESTIONS ???
# [top](#Contents)
#
# 1. Not sure how to interpret my ACF & PACF plot?
# 2. Should i use AR, MA, ARMA or ARIMA model?
# 3. What values of $p$, $d$, and $q$ should i use? Should i do gridsearch?
# 4. Should i plot the residuals?
