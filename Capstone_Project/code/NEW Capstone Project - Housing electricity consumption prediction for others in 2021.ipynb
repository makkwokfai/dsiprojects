# %% [markdown]
# # DSI 18 - Capstone Project
#
# # Households Electricity Consumption Prediction 2021

# %% [markdown]
# ## Contents
#
# - [1. Objective](#1.-Objective)
#     - [1.1. Problem Statement](#1.1.-Problem-Statement)
#     - [1.2. Data Sources](#1.2.-Data-Sources)
# - [2. Check the data given](#2.-Check-the-data-given)
#     - [2.1. Definition of sunshine hours](#2.1.-Definition-of-sunshine-hours)
# - [3. Clean the data](#3.-Clean-the-data)
#     - [3.1. Clean the data](#3.1.-Clean-the-data)
#     - [3.2. Combine the data](#3.2.-Combine-the-data)
# - [4. EDA](#4.-EDA)
#     - [4.1. Correlation of sunshine](#4.1.-Correlation-of-sunshine)
#     - [4.2. Analyze different type of properties](#4.2.-Analyze-different-type-of-properties)
#     - [4.3. Analyze changes in mean sunshine hours for different years](#4.3.-Analyze-changes-in-mean-sunshine-hours-for-different-years)
# - [5. Autocorrelation](#5.-Autocorrelation)
# - [6. Difference the data](#6.-Difference-the-data)
# - [7. Apply Dickey Fuller test for original/differenced data](#7.-Apply-Dickey-Fuller-test-for-original/differenced-data)
# - [8. Train/test split for original/differenced data](#8.-Train/test-split-for-original/differenced-data)
# - [9. Plotting ACF and PACF](#9.-Plotting-ACF-and-PACF)
# - [10. Modeling](#10.-Modeling)
#     - [10.1. Modeling for others data](#10.1.-Modeling-for-others-data)
# - [11. Conclusion](#11.-Conclusion)
# - [12. References](#12.-References)

# %% [markdown]
# ## 1. Objective
# [top](#Contents)

# %% [markdown]
# ###### Based on the households electricity consumption in Singapore in 2005 - 2020, we are going to predict the households electricity consumption in Singapore for 2021.

# %% [markdown]
# ### 1.1. Problem Statement
# [top](#Contents)

# %% [markdown]
# As a data scientist engaged by Singapore Poower, i am going to analyze the trend of household electricity consumption in Singapore.
#
# Based on the data from 2005 to 2020, i am going to predict the household electricity consumption for 2021.

# %% [markdown]
# ### 1.2. Data Sources
# [top](#Contents)

# %% [markdown]
# Past year Energy Consumption in Singapore from 2005 to 2020:
#
# https://www.kaggle.com/zyc191/energy-consumption-singapore-from-opendata

# %% [markdown]
# ## 2. Check the data given
# [top](#Contents)

# %% [markdown]
# **2 set** of datas are given by Kaggle, we will browse through it one-by-one.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
sunshine = pd.read_csv('../datasets/sunshine_duration_monthly_mean_daily_duration.csv')
sunshine.head()
# Out:
#      month  mean_sunshine_hrs
# 0  1982-01                5.6
# 1  1982-02                7.6
# 2  1982-03                5.1
# 3  1982-04                4.7
# 4  1982-05                5.8

# %%
sunshine.tail()
# Out:
#        month  mean_sunshine_hrs
# 461  2020-06                4.3
# 462  2020-07                5.7
# 463  2020-08                6.4
# 464  2020-09                4.8
# 465  2020-10                4.3

# %%
sunshine.describe()
# Out:
#        mean_sunshine_hrs
# count         466.000000
# mean            5.674464
# std             1.207740
# min             2.700000
# 25%             4.800000
# 50%             5.600000
# 75%             6.400000
# max             9.300000

# %%
household = pd.read_csv('../datasets/total_household_electricity_consumption_2005_2020.csv')
household.head()
# Out:
#      month  overall  public_housing  1-room_2-room  3-room  4-room  \
# 0  2019-01    594.1           343.4           11.5    61.1   143.3
# 1  2019-02    613.6           356.0           11.7    62.3   148.5
# 2  2019-03    598.2           340.9           11.2    59.6   142.0
# 3  2019-04    653.1           374.6           12.3    66.2   155.9
# 4  2019-05    670.5           385.9           12.8    68.3   160.7
#
#    5-room_and_executive  private_housing  private_apts_and_condo  \
# 0                 127.4            249.8                   163.0
# 1                 133.4            256.7                   167.6
# 2                 128.0            256.5                   167.8
# 3                 140.2            277.6                   183.6
# 4                 144.0            283.7                   190.0
#
#    landed_properties  others
# 0               86.9     0.8
# 1               89.1     0.8
# 2               88.7     0.8
# 3               94.0     0.9
# 4               93.7     0.9

# %%
household.describe()
# Out:
#           overall  public_housing  1-room_2-room      3-room      4-room  \
# count  187.000000      187.000000     187.000000  187.000000  187.000000
# mean   568.124599      339.652406       8.560963   61.706417  137.516043
# std     69.077311       36.751159       2.528212    5.810970   16.690254
# min    437.100000      270.800000       5.300000   50.400000  107.100000
# 25%    518.850000      314.550000       6.400000   57.900000  126.400000
# 50%    563.500000      337.800000       7.600000   61.500000  136.400000
# 75%    612.550000      363.850000      10.700000   65.350000  148.350000
# max    886.700000      515.200000      18.100000   87.100000  215.200000
#
#        5-room_and_executive  private_housing  private_apts_and_condo  \
# count            187.000000       187.000000              187.000000
# mean             131.865775       227.499465              142.231016
# std               12.778081        33.238376               26.868469
# min              106.000000       165.500000               94.800000
# 25%              123.300000       201.750000              121.350000
# 50%              131.800000       225.900000              138.600000
# 75%              139.500000       251.200000              162.150000
# max              194.800000       370.600000              259.600000
#
#        landed_properties      others
# count         187.000000  187.000000
# mean           85.270588    0.972193
# std             7.090979    0.137086
# min            70.400000    0.600000
# 25%            80.600000    0.900000
# 50%            85.900000    1.000000
# 75%            90.000000    1.100000
# max           113.700000    1.300000

# %% [markdown]
# #### Interpretation:
#
# We want to predict the household energy consumption in 2021, it is necessary to do it base on past years result. I intend to break-it down and check the energy consumption for different types of household seperatly, and forecast the future consumption.
#
# These are the data we are using:
#
# |Data Given|Duration|Frequency|
# |---|---|---|
# |Mean daily sunshine|Jan 1982 - Oct 2020|Monthly|
# |Household electricity consumption|Jan 2005 - Jul 2020|Monthly|
#
# The mean daily sunshine has an average of 5.6 hours and a standard deviation of 1.2 hours. For electricity consumption, it varies for different type of properties, with average values 8.6 - 142 KWh, and a standard deviation of 2.5 - 26.9 KWh.

# %% [markdown]
# ### 2.1. Definition of sunshine hours
# [top](#Contents)

# %% [markdown]
# Given the theoretical maximum of daytime duration for a given location, there is also a practical consideration at which point the amount of daylight is sufficient to be treated as a "sunshine hour". "Bright" sunshine hours represent the total hours when the sunlight is stronger than a specified threshold, as opposed to just "visible" hours. "Visible" sunshine, for example, occurs around sunrise and sunset, but is not strong enough to excite the sensor.

# %% [markdown]
# <img src = "../image/Sunshine.PNG">

# %% [markdown]
# According to Wikipedia, Singapore has a sunshine duration of about 129.2 - 192.7 hours per month. It is a general indicator of cloudines of a location. It is equivalent to 4.3 - 6.4 hours per day, which match the result in the `total_household_electricity_consumption_2005_2020.csv` data.

# %% [markdown]
# ## 3. Clean the data
# [top](#Contents)

# %% [markdown]
# ### 3.1. Clean the data
# [top](#Contents)

# %% [markdown]
# We will first check the duration of the data given.

# %% [markdown]
# #### 1. `sunshine` data.

# %%
sunshine['month'].unique()
# Out:
# array(['1982-01', '1982-02', '1982-03', '1982-04', '1982-05', '1982-06',
#        '1982-07', '1982-08', '1982-09', '1982-10', '1982-11', '1982-12',
#        '1983-01', '1983-02', '1983-03', '1983-04', '1983-05', '1983-06',
#        '1983-07', '1983-08', '1983-09', '1983-10', '1983-11', '1983-12',
#        '1984-01', '1984-02', '1984-03', '1984-04', '1984-05', '1984-06',
#        '1984-07', '1984-08', '1984-09', '1984-10', '1984-11', '1984-12',
#        '1985-01', '1985-02', '1985-03', '1985-04', '1985-05', '1985-06',
#        '1985-07', '1985-08', '1985-09', '1985-10', '1985-11', '1985-12',
#        '1986-01', '1986-02', '1986-03', '1986-04', '1986-05', '1986-06',
#        '1986-07', '1986-08', '1986-09', '1986-10', '1986-11', '1986-12',
#        '1987-01', '1987-02', '1987-03', '1987-04', '1987-05', '1987-06',
#        '1987-07', '1987-08', '1987-09', '1987-10', '1987-11', '1987-12',
#        '1988-01', '1988-02', '1988-03', '1988-04', '1988-05', '1988-06',
#        '1988-07', '1988-08', '1988-09', '1988-10', '1988-11', '1988-12',
#        '1989-01', '1989-02', '1989-03', '1989-04', '1989-05', '1989-06',
#        '1989-07', '1989-08', '1989-09', '1989-10', '1989-11', '1989-12',
#        '1990-01', '1990-02', '1990-03', '1990-04', '1990-05', '1990-06',
#        '1990-07', '1990-08', '1990-09', '1990-10', '1990-11', '1990-12',
#        '1991-01', '1991-02', '1991-03', '1991-04', '1991-05', '1991-06',
#        '1991-07', '1991-08', '1991-09', '1991-10', '1991-11', '1991-12',
#        '1992-01', '1992-02', '1992-03', '1992-04', '1992-05', '1992-06',
#        '1992-07', '1992-08', '1992-09', '1992-10', '1992-11', '1992-12',
#        '1993-01', '1993-02', '1993-03', '1993-04', '1993-05', '1993-06',
#        '1993-07', '1993-08', '1993-09', '1993-10', '1993-11', '1993-12',
#        '1994-01', '1994-02', '1994-03', '1994-04', '1994-05', '1994-06',
#        '1994-07', '1994-08', '1994-09', '1994-10', '1994-11', '1994-12',
#        '1995-01', '1995-02', '1995-03', '1995-04', '1995-05', '1995-06',
#        '1995-07', '1995-08', '1995-09', '1995-10', '1995-11', '1995-12',
#        '1996-01', '1996-02', '1996-03', '1996-04', '1996-05', '1996-06',
#        '1996-07', '1996-08', '1996-09', '1996-10', '1996-11', '1996-12',
#        '1997-01', '1997-02', '1997-03', '1997-04', '1997-05', '1997-06',
#        '1997-07', '1997-08', '1997-09', '1997-10', '1997-11', '1997-12',
#        '1998-01', '1998-02', '1998-03', '1998-04', '1998-05', '1998-06',
#        '1998-07', '1998-08', '1998-09', '1998-10', '1998-11', '1998-12',
#        '1999-01', '1999-02', '1999-03', '1999-04', '1999-05', '1999-06',
#        '1999-07', '1999-08', '1999-09', '1999-10', '1999-11', '1999-12',
#        '2000-01', '2000-02', '2000-03', '2000-04', '2000-05', '2000-06',
#        '2000-07', '2000-08', '2000-09', '2000-10', '2000-11', '2000-12',
#        '2001-01', '2001-02', '2001-03', '2001-04', '2001-05', '2001-06',
#        '2001-07', '2001-08', '2001-09', '2001-10', '2001-11', '2001-12',
#        '2002-01', '2002-02', '2002-03', '2002-04', '2002-05', '2002-06',
#        '2002-07', '2002-08', '2002-09', '2002-10', '2002-11', '2002-12',
#        '2003-01', '2003-02', '2003-03', '2003-04', '2003-05', '2003-06',
#        '2003-07', '2003-08', '2003-09', '2003-10', '2003-11', '2003-12',
#        '2004-01', '2004-02', '2004-03', '2004-04', '2004-05', '2004-06',
#        '2004-07', '2004-08', '2004-09', '2004-10', '2004-11', '2004-12',
#        '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06',
#        '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12',
#        '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06',
#        '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12',
#        '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06',
#        '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12',
#        '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
#        '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12',
#        '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#        '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12',
#        '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06',
#        '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12',
#        '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06',
#        '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12',
#        '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
#        '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
#        '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
#        '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#        '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#        '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#        '2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#        '2020-07', '2020-08', '2020-09', '2020-10'], dtype=object)

# %% [markdown]
# For sunshine data, we are given from 1982-01 to 2020-10, all in order. Since we only have household data from 2005 onwards, and we do not have full year data for 2020, so we will extract only data from 2005-01 to 2020-07.

# %%
# Extract result from 2005-01 to 2020-07
sunshine_extract = sunshine[(sunshine['month'] > '2004-12') & (sunshine['month'] < '2020-08')]
sunshine_extract.head()
# Out:
#        month  mean_sunshine_hrs
# 276  2005-01                6.5
# 277  2005-02                9.1
# 278  2005-03                7.2
# 279  2005-04                7.0
# 280  2005-05                5.5

# %%
# Set the month as index
sunshine_extract.set_index('month', inplace=True)
sunshine_extract.head()
# Out:
#          mean_sunshine_hrs
# month
# 2005-01                6.5
# 2005-02                9.1
# 2005-03                7.2
# 2005-04                7.0
# 2005-05                5.5

# %% [markdown]
# #### 2. `household` data.

# %%
household['month'].unique()
# Out:
# array(['2019-01', '2019-02', '2019-03', '2019-04', '2019-05', '2019-06',
#        '2019-07', '2019-08', '2019-09', '2019-10', '2019-11', '2019-12',
#        '2005-01', '2005-02', '2005-03', '2005-04', '2005-05', '2005-06',
#        '2005-07', '2005-08', '2005-09', '2005-10', '2005-11', '2005-12',
#        '2006-01', '2006-02', '2006-03', '2006-04', '2006-05', '2006-06',
#        '2006-07', '2006-08', '2006-09', '2006-10', '2006-11', '2006-12',
#        '2007-01', '2007-02', '2007-03', '2007-04', '2007-05', '2007-06',
#        '2007-07', '2007-08', '2007-09', '2007-10', '2007-11', '2007-12',
#        '2008-01', '2008-02', '2008-03', '2008-04', '2008-05', '2008-06',
#        '2008-07', '2008-08', '2008-09', '2008-10', '2008-11', '2008-12',
#        '2009-01', '2009-02', '2009-03', '2009-04', '2009-05', '2009-06',
#        '2009-07', '2009-08', '2009-09', '2009-10', '2009-11', '2009-12',
#        '2010-01', '2010-02', '2010-03', '2010-04', '2010-05', '2010-06',
#        '2010-07', '2010-08', '2010-09', '2010-10', '2010-11', '2010-12',
#        '2011-01', '2011-02', '2011-03', '2011-04', '2011-05', '2011-06',
#        '2011-07', '2011-08', '2011-09', '2011-10', '2011-11', '2011-12',
#        '2012-01', '2012-02', '2012-03', '2012-04', '2012-05', '2012-06',
#        '2012-07', '2012-08', '2012-09', '2012-10', '2012-11', '2012-12',
#        '2013-01', '2013-02', '2013-03', '2013-04', '2013-05', '2013-06',
#        '2013-07', '2013-08', '2013-09', '2013-10', '2013-11', '2013-12',
#        '2014-01', '2014-02', '2014-03', '2014-04', '2014-05', '2014-06',
#        '2014-07', '2014-08', '2014-09', '2014-10', '2014-11', '2014-12',
#        '2015-01', '2015-02', '2015-03', '2015-04', '2015-05', '2015-06',
#        '2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#        '2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#        '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12',
#        '2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06',
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04', '2018-05', '2018-06',
#        '2018-07', '2018-08', '2018-09', '2018-10', '2018-11', '2018-12',
#        '2020-01', '2020-02', '2020-03', '2020-04', '2020-05', '2020-06',
#        '2020-07'], dtype=object)

# %% [markdown]
# For household data, we are given data from 2005-01 to 2020-07, not in order, we will sort the data.

# %%
# Sort the result
household  = household.sort_values('month')
household = household.reset_index(drop=True)

# %%
# Set the month as index
household.set_index('month', inplace=True)
household.head()
# Out:
#          overall  public_housing  1-room_2-room  3-room  4-room  \
# month
# 2005-01    447.8           280.7            6.3    52.9   111.1
# 2005-02    437.1           270.8            6.0    51.5   107.3
# 2005-03    479.7           295.4            6.1    55.4   117.1
# 2005-04    533.6           331.6            6.9    61.4   131.5
# 2005-05    535.0           330.5            6.8    61.5   130.9
#
#          5-room_and_executive  private_housing  private_apts_and_condo  \
# month
# 2005-01                 110.4            166.2                    95.8
# 2005-02                 106.0            165.5                    94.8
# 2005-03                 116.8            183.3                   104.8
# 2005-04                 131.8            200.9                   117.9
# 2005-05                 131.2            203.5                   120.4
#
#          landed_properties  others
# month
# 2005-01               70.4     0.9
# 2005-02               70.7     0.9
# 2005-03               78.5     1.0
# 2005-04               83.1     1.1
# 2005-05               83.1     1.1

# %%
household.tail()
# Out:
#          overall  public_housing  1-room_2-room  3-room  4-room  \
# month
# 2020-03    620.6           354.6           12.3    62.0   148.2
# 2020-04    669.9           383.4           13.3    66.8   160.6
# 2020-05    663.3           381.9           13.7    67.4   160.2
# 2020-06    869.7           501.6           17.3    86.8   209.3
# 2020-07    886.7           515.2           18.1    87.1   215.2
#
#          5-room_and_executive  private_housing  private_apts_and_condo  \
# month
# 2020-03                 132.1            265.2                   175.3
# 2020-04                 142.6            285.7                   187.7
# 2020-05                 140.6            280.5                   183.9
# 2020-06                 188.2            367.0                   253.3
# 2020-07                 194.8            370.6                   259.6
#
#          landed_properties  others
# month
# 2020-03               90.0     0.8
# 2020-04               97.9     0.9
# 2020-05               96.6     1.0
# 2020-06              113.7     1.1
# 2020-07              111.0     1.0

# %% [markdown]
# ### 3.2. Combine the data
# [top](#Contents)

# %%
energy_final = pd.concat([sunshine_extract , household] , axis=1)

# %%
energy_final.head()
# Out:
#          mean_sunshine_hrs  overall  public_housing  1-room_2-room  3-room  \
# month
# 2005-01                6.5    447.8           280.7            6.3    52.9
# 2005-02                9.1    437.1           270.8            6.0    51.5
# 2005-03                7.2    479.7           295.4            6.1    55.4
# 2005-04                7.0    533.6           331.6            6.9    61.4
# 2005-05                5.5    535.0           330.5            6.8    61.5
#
#          4-room  5-room_and_executive  private_housing  \
# month
# 2005-01   111.1                 110.4            166.2
# 2005-02   107.3                 106.0            165.5
# 2005-03   117.1                 116.8            183.3
# 2005-04   131.5                 131.8            200.9
# 2005-05   130.9                 131.2            203.5
#
#          private_apts_and_condo  landed_properties  others
# month
# 2005-01                    95.8               70.4     0.9
# 2005-02                    94.8               70.7     0.9
# 2005-03                   104.8               78.5     1.0
# 2005-04                   117.9               83.1     1.1
# 2005-05                   120.4               83.1     1.1

# %%
energy_final.tail()
# Out:
#          mean_sunshine_hrs  overall  public_housing  1-room_2-room  3-room  \
# month
# 2020-03                7.6    620.6           354.6           12.3    62.0
# 2020-04                7.1    669.9           383.4           13.3    66.8
# 2020-05                5.7    663.3           381.9           13.7    67.4
# 2020-06                4.3    869.7           501.6           17.3    86.8
# 2020-07                5.7    886.7           515.2           18.1    87.1
#
#          4-room  5-room_and_executive  private_housing  \
# month
# 2020-03   148.2                 132.1            265.2
# 2020-04   160.6                 142.6            285.7
# 2020-05   160.2                 140.6            280.5
# 2020-06   209.3                 188.2            367.0
# 2020-07   215.2                 194.8            370.6
#
#          private_apts_and_condo  landed_properties  others
# month
# 2020-03                   175.3               90.0     0.8
# 2020-04                   187.7               97.9     0.9
# 2020-05                   183.9               96.6     1.0
# 2020-06                   253.3              113.7     1.1
# 2020-07                   259.6              111.0     1.0

# %%
energy_final.shape
# Out:
# (187, 11)

# %% [markdown]
# ## 4. EDA
# [top](#Contents)

# %% [markdown]
# ### 4.1. Correlation of sunshine
# [top](#Contents)

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(energy_final.corr() , cmap='icefire',mask=np.triu(energy_final.corr()),annot=True)
# Out:
# <AxesSubplot:>

# %%
sunshine = energy_final.corr()[['mean_sunshine_hrs']]

# %%
sunshine.sort_values(by='mean_sunshine_hrs')
# Out:
#                         mean_sunshine_hrs
# others                          -0.241193
# 5-room_and_executive            -0.103731
# 3-room                          -0.075119
# public_housing                  -0.042945
# overall                         -0.008435
# 4-room                          -0.007537
# landed_properties               -0.001735
# private_housing                  0.030669
# private_apts_and_condo           0.038408
# 1-room_2-room                    0.123545
# mean_sunshine_hrs                1.000000

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 9))

# Create scatter plot of high prices versus volume.
plt.scatter(energy_final['mean_sunshine_hrs'],
            energy_final['1-room_2-room']);

sns.regplot(x="1-room_2-room", y="mean_sunshine_hrs", data=energy_final);

plt.title("Mean Sunshine Hours versus Energy Consumption for 1-Room & 2-Room HDB" , fontsize=20)
plt.ylabel("Energy Consumption for 1-Room & 2-Room HDB", fontsize = 12)
plt.xlabel("Mean Sunshine Hours", fontsize = 12);

# %% [markdown]
# #### Interpretation:
#
# There is not much correlation between the mean sunshine hours to energy consumption.
#
# Before doing the correlation plot, i was thinking Energy Consumption should have a negative correlation with Sunshine Hours, as longer the sunlight should mean residents have a shorter duration on the electrical light. However, when i plot the correlation all the data, the result is different from my expectation, as there is not much correlation from mean sunshine hours to electricity consumption.
#
# I think that's because of the data we used, as we capture the "bright" sunshine hours for each day. "Bright" sunshine hours represent the total hours when the sunlight is stronger than a specified threshold, as opposed to just "visible" hours. "Visible" sunshine, for example, occurs around sunrise and sunset, but is not strong enough to excite the sensor. My expectation should apply only for "visible" sunshine, but not for this case.

# %% [markdown]
# ### 4.2. Analyze different type of properties
# [top](#Contents)

# %% [markdown]
# For energy consumption of households, it can be further seperated into different residential types:
#
# - Public Housing
#         1. 1-room_2-room
#         2. 3-room
#         3. 4-room
#         4. 5-room_and_executive
# - Private Housing
#         1. private_apts_and_condo
#         2. landed_properties
# - others
#
# We will look at the energy comsumpted by each residential types one-by-one.

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['others'])
plt.title('Plot of Electricity Consumption for others' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Electricity Consumption in KWh',fontsize=18)
# Out:
# Text(0, 0.5, 'Electricity Consumption in KWh')

# %% [markdown]
# #### Interpretation:
#
# We see that the electricity consumption for others decrease over the years.

# %% [markdown]
# ### 4.3. Analyze changes in mean sunshine hours for different years
# [top](#Contents)

# %%
plt.figure(figsize=(30, 12))
plt.plot(energy_final['mean_sunshine_hrs'])
plt.title('Plot of Mean Sunshine hours over the year' , fontsize=20)
plt.xlabel('Time',fontsize=18)
plt.xticks(rotation=90, fontsize=6)
plt.ylabel('Mean Sunshine Hours',fontsize=18)
# Out:
# Text(0, 0.5, 'Mean Sunshine Hours')

# %% [markdown]
# #### Interpretation:
#
# The mean sunshine are between 3 - 9 hours, there is no significant changes in the number of hours over the year. We usually observe a longer sunshine in January, and shorter sunshine in November.

# %% [markdown]
# ## 5. Autocorrelation
# [top](#Contents)

# %% [markdown]
# By looking at the households electricity consumption, it seems like that the result is cyclical. We will look at 3 lags interval:
# - 3 months
# - 6 months
# - 1 year (12 months)

# %% [markdown]
# #### Autocorrelation for others data

# %%
print(f'Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=3),4)}')
print(f'Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=6),4)}')
print(f'Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: {round(energy_final["others"].autocorr(lag=12),4)}')
# Out:
# Autocorrelation between Electricity Consumption and 3-months lag Electricity Consumption: 0.5533
# Autocorrelation between Electricity Consumption and 6-months lag Electricity Consumption: 0.5811
# Autocorrelation between Electricity Consumption and 12-months lag Electricity Consumption: 0.8116

# %% [markdown]
# #### Interpretation:
#
# By looking at the 3 lags interval we have selected: 3-months, 6-months & 12-months, the 12-months (1 year) lag of electricity consumption is strongly correlated with the current electricity consumption. This would suggest that there might be a seasonal influence working on electricity consumption separated by one year.

# %% [markdown]
# $$
# \begin{eqnarray*}
#     Y_t &=& \mu + \beta(Y_{t-12}) + \varepsilon_t \\
# \end{eqnarray*}
# $$

# %% [markdown]
# ## 6. Difference the data
# [top](#Contents)

# %% [markdown]
# #### Difference others data

# %%
energy_final['others_1stdiff'] = energy_final['others'].diff(1)
energy_final['others_2nddiff'] = energy_final['others'].diff(1).diff(1)
energy_final['others_3rddiff'] = energy_final['others'].diff(1).diff(1).diff(1)
energy_final['others_4thdiff'] = energy_final['others'].diff(1).diff(1).diff(1).diff(1)
energy_final['others_5thdiff'] = energy_final['others'].diff(1).diff(1).diff(1).diff(1).diff(1)

# %% [markdown]
# ## 7. Apply Dickey Fuller test for original/differenced data
# [top](#Contents)

# %% [markdown]
# Dickey Fuller test is used to determine whether or not the data are stationary.

# %%
# Import Augmented Dickey-Fuller Test
from statsmodels.tsa.stattools import adfuller

# Define function to easily interpret results.
def interpret_dftest(dftest):
    dfoutput = pd.Series(dftest[0:2], index=['Test Statistic','p-value'])
    return dfoutput

# %% [markdown]
# #### Dickey Fuller test for others original/differenced data

# %%
# Execute test on no difference data.
interpret_dftest(adfuller(energy_final['others']))
# Out:
# Test Statistic   -0.607451
# p-value           0.869290
# dtype: float64

# %%
# Execute test on 1-differenced data.
interpret_dftest(adfuller(energy_final['others_1stdiff'].iloc[1:]))
# Out:
# Test Statistic   -6.572510e+00
# p-value           7.871578e-09
# dtype: float64

# %%
# Execute test on 2-differenced data.
interpret_dftest(adfuller(energy_final['others_2nddiff'].iloc[2:]))
# Out:
# Test Statistic   -9.861284e+00
# p-value           4.226529e-17
# dtype: float64

# %% [markdown]
# #### Interpretation:
#
# I will run the Dicker Fuller test after apply difference on the data several times. By comparing the result, it is found that 2-times differences for 1 room & 2 room is preferred.

# %% [markdown]
# ## 8. Train/test split for original/differenced data
# [top](#Contents)

# %% [markdown]
# Modeling with time series data presents unique challenges because our observations are not independent of one another.
#
# So, in splitting the data into `train` and `test` sets, **we cannot split randomly**. Use the first *75%* of observations as training data and the following 25% for test data (both rounded to year).

# %%
print(f'Number of years in the observations: {len(energy_final)/12}')
print(f'Number of years in the training observations: {round(len(energy_final)/12 * 0.75)}')
print(f'Number of years in the testing observations: {len(energy_final)/12 - round(len(energy_final)/12 * 0.75)}')
# Out:
# Number of years in the observations: 15.583333333333334
# Number of years in the training observations: 12
# Number of years in the testing observations: 3.583333333333334

# %% [markdown]
# Therefore, we set the first 11 years (2005 - 2015) of the observation as our train data, and last 4.5 years (Jan 2016 - Jun 2020) of our observation as our test data.

# %%
11 * 12
# Out:
# 132

# %%
energy_final.iloc[131:133]
# Out:
#          mean_sunshine_hrs  overall  public_housing  1-room_2-room  3-room  \
# month
# 2015-12                5.3    622.4           370.3           10.7    66.0
# 2016-01                7.2    570.2           336.7           10.2    61.2
#
#          4-room  5-room_and_executive  private_housing  \
# month
# 2015-12   151.9                 141.7            251.2
# 2016-01   137.9                 127.4            232.7
#
#          private_apts_and_condo  landed_properties  others  others_1stdiff  \
# month
# 2015-12                   160.5               90.7     0.9             0.0
# 2016-01                   148.4               84.3     0.9             0.0
#
#          others_2nddiff  others_3rddiff  others_4thdiff  others_5thdiff
# month
# 2015-12             0.0             0.0             0.0            -0.1
# 2016-01             0.0             0.0             0.0             0.0

# %%
def train_test_plot(train, test):
    plt.figure(figsize=(30, 12))
    plt.plot(train, c='blue')
    plt.plot(test, c='orange');
    plt.xlabel('Time',fontsize=18)
    plt.xticks(rotation=90, fontsize=6)
    plt.ylabel('Electricity Consumption in KWh',fontsize=18)

# %% [markdown]
# #### Train/Test split for others data

# %%
# Train/test split for original data

train_others = energy_final['others'].iloc[:132,]
test_others = energy_final['others'].iloc[132:,]

train_test_plot(train_others , test_others)

# %%
# Sanity check
train_others.head()
# Out:
# month
# 2005-01    0.9
# 2005-02    0.9
# 2005-03    1.0
# 2005-04    1.1
# 2005-05    1.1
# Name: others, dtype: float64

# %%
# Train/test split for 1st-differenced data

train_others_1stdiff = energy_final['others_1stdiff'].iloc[:132,]
test_others_1stdiff = energy_final['others_1stdiff'].iloc[132:,]

train_test_plot(train_others_1stdiff , test_others_1stdiff)

# %%
# Sanity check
train_others_1stdiff.head()
# Out:
# month
# 2005-01    NaN
# 2005-02    0.0
# 2005-03    0.1
# 2005-04    0.1
# 2005-05    0.0
# Name: others_1stdiff, dtype: float64

# %%
# Train/test split for 2nd-differenced data

train_others_2nddiff = energy_final['others_2nddiff'].iloc[:132,]
test_others_2nddiff = energy_final['others_2nddiff'].iloc[132:,]

train_test_plot(train_others_2nddiff , test_others_2nddiff)

# %%
# Sanity check
train_others_2nddiff.head()
# Out:
# month
# 2005-01             NaN
# 2005-02             NaN
# 2005-03    1.000000e-01
# 2005-04    1.110223e-16
# 2005-05   -1.000000e-01
# Name: others_2nddiff, dtype: float64

# %% [markdown]
# ## 9. Plotting ACF and PACF
# [top](#Contents)

# %% [markdown]
# From the autocorrelation result, the 12-months lag of electricity consumption is strongly correlated with the current month's electricity consumption. This would suggest that there may be seasonal influence working on electricity consumption seperated by one year.
#
# We will plot the 12-months `ACF` and 12-months `PACF` plot now.

# %% [markdown]
# #### ACF & PACF for others data
# [top](#Contents)

# %%
# Generate autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_acf(train_others, lags = 12);

# %%
# Generate partial autocorrelation plot on training data.
plt.figure(figsize=(30, 12))
plot_pacf(train_others, lags = 12);

# %% [markdown]
# ## 10. Modeling
# [top](#Contents)

# %%
import warnings
warnings.simplefilter('ignore')

from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### 10.1. Modeling for others data
# [top](#Contents)

# %% [markdown]
# Using for loop, i will find the most suitable value of $p$ & $q$ for the model.

# %%
# Starting AIC, p, and q.
best_aic = 99 * (10 ** 16)
best_p = 0
best_q = 0

# Use nested for loop to iterate over values of p and q.
for p in range(5):
    for q in range(5):
        
        # Insert try and except statements.
        try:
            
            # Fitting an ARIMA(p, 2, q) model.
            print(f'Attempting to fit ARIMA({p},2,{q})')
            
            # Instantiate ARIMA model.
            arima = ARIMA(endog = train_others_2nddiff.iloc[2:],
                          order = (p,2,q)) # values of p, d, q
            
            # Fit ARIMA model.
            model = arima.fit()

            # Print out AIC for ARIMA(p, 2, q) model.
            print(f'The AIC for ARIMA({p},2,{q}) is: {model.aic}')

            # Is my current model's AIC better than our best_aic?
            if model.aic < best_aic:
                
                # If so, let's overwrite best_aic, best_p, and best_q.
                best_aic = model.aic
                best_p = p
                best_q = q

        except:
            pass
print()
print()
print('MODEL FINISHED!')
print(f'Our model that minimizes AIC on the training data is the ARIMA({best_p},2,{best_q}).')
print(f'This model has an AIC of {best_aic}.')
# Out:
# Attempting to fit ARIMA(0,2,0)
# The AIC for ARIMA(0,2,0) is: 156.6069685254755
# Attempting to fit ARIMA(0,2,1)
# The AIC for ARIMA(0,2,1) is: 8.015594075742001
# Attempting to fit ARIMA(0,2,2)
# The AIC for ARIMA(0,2,2) is: -123.63648947934627
# Attempting to fit ARIMA(0,2,3)
# The AIC for ARIMA(0,2,3) is: -205.10395719962366
# Attempting to fit ARIMA(0,2,4)
# Attempting to fit ARIMA(1,2,0)
# The AIC for ARIMA(1,2,0) is: 51.057992569373255
# Attempting to fit ARIMA(1,2,1)
# Attempting to fit ARIMA(1,2,2)
# Attempting to fit ARIMA(1,2,3)
# Attempting to fit ARIMA(1,2,4)
# Attempting to fit ARIMA(2,2,0)
# The AIC for ARIMA(2,2,0) is: -28.55350175035676
# Attempting to fit ARIMA(2,2,1)
# Attempting to fit ARIMA(2,2,2)
# Attempting to fit ARIMA(2,2,3)
# The AIC for ARIMA(2,2,3) is: -170.29976102312196
# Attempting to fit ARIMA(2,2,4)
# The AIC for ARIMA(2,2,4) is: -192.9086631338422
# Attempting to fit ARIMA(3,2,0)
# The AIC for ARIMA(3,2,0) is: -47.976226862042154
# Attempting to fit ARIMA(3,2,1)
# Attempting to fit ARIMA(3,2,2)
# Attempting to fit ARIMA(3,2,3)
# The AIC for ARIMA(3,2,3) is: -167.69179992215436
# Attempting to fit ARIMA(3,2,4)
# The AIC for ARIMA(3,2,4) is: -186.3223990983746
# Attempting to fit ARIMA(4,2,0)
# The AIC for ARIMA(4,2,0) is: -61.82574793661985
# Attempting to fit ARIMA(4,2,1)
# Attempting to fit ARIMA(4,2,2)
# The AIC for ARIMA(4,2,2) is: -155.26237764464236
# Attempting to fit ARIMA(4,2,3)
# The AIC for ARIMA(4,2,3) is: -217.41119342226182
# Attempting to fit ARIMA(4,2,4)
#
#
# MODEL FINISHED!
# Our model that minimizes AIC on the training data is the ARIMA(4,2,3).
# This model has an AIC of -217.41119342226182.

# %%
# Instantiate an ARIMA(4,2,3) model on training data.
# Note this training data consists of the 
# time periods 0 through 132.
ar1 = ARIMA(endog = train_others_2nddiff.iloc[2:],
            order = (4, 2, 3)) # (p, d, q)

# Fit ARIMA(4,2,3) model.
model = ar1.fit()

# Generate predictions based on test set.
# Start at time period 130 and end at 185.
preds1 = model.predict(start=130, end=185)

# Evaluate predictions.
mean_squared_error(test_others_2nddiff, preds1.iloc[:-1])
# Out:
# 0.015139776915900406

# %%
# Check the data format
train_others_2nddiff.iloc[2:].head()
# Out:
# month
# 2005-03    1.000000e-01
# 2005-04    1.110223e-16
# 2005-05   -1.000000e-01
# 2005-06    0.000000e+00
# 2005-07   -1.000000e-01
# Name: others_2nddiff, dtype: float64

# %%
# Check the data format
test_others_2nddiff.head()
# Out:
# month
# 2016-01    0.0
# 2016-02   -0.1
# 2016-03    0.1
# 2016-04    0.2
# 2016-05   -0.2
# Name: others_2nddiff, dtype: float64

# %%
# Check the data format
preds1.head()
# Out:
# 2016-01-01   -0.002204
# 2016-02-01    0.006505
# 2016-03-01   -0.004860
# 2016-04-01    0.000221
# 2016-05-01    0.000361
# Freq: MS, dtype: float64

# %% [markdown]
# preds1 has days. need to remove it in-order to combine these with train/test to plot.

# %%
# changing datetime index into column for manipulation
preds1_clean = preds1.reset_index()
preds1_clean.head()
# Out:
#        index         0
# 0 2016-01-01 -0.002204
# 1 2016-02-01  0.006505
# 2 2016-03-01 -0.004860
# 3 2016-04-01  0.000221
# 4 2016-05-01  0.000361

# %%
# applying lambda function to change format of "index" datetime column into (YYYY-MM)
preds1_clean["index"] = preds1_clean['index'].apply(lambda x:x.strftime('%Y-%m'))
preds1_clean.head()
# Out:
#      index         0
# 0  2016-01 -0.002204
# 1  2016-02  0.006505
# 2  2016-03 -0.004860
# 3  2016-04  0.000221
# 4  2016-05  0.000361

# %%
# resetting the "index" from the datetime column
preds1_clean.set_index("index", inplace = True)
preds1_clean.head()
# Out:
#                 0
# index
# 2016-01 -0.002204
# 2016-02  0.006505
# 2016-03 -0.004860
# 2016-04  0.000221
# 2016-05  0.000361

# %%
# Plot data.
plt.figure(figsize=(30, 12))
plt.plot(train_others_2nddiff.iloc[2:], color = 'blue')
plt.plot(test_others_2nddiff, color = 'orange')
plt.plot(preds1_clean, color = 'green')
plt.title(label = 'Electricity Consumption for other housing type with ARIMA(4,2,3) Predictions', fontsize=22)
plt.xticks(rotation=90, fontsize=6)
plt.show();

# %% [markdown]
# ARIMA model does not give a good prediction, we will try Seasonal ARIMA (SARIMA) instead. It includes a seasonal component that will allow us to also account for seasonality that occurs over time.

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
# Starting MSE and (P, D, Q).
mse = 99 * (10 ** 16)
final_P = 0
final_D = 0
final_Q = 0

for P in range(3):
    for Q in range(3):
        for D in range(3):
            try:
                # Instantiate SARIMA model.
                sarima = SARIMAX(endog = train_others_2nddiff.iloc[2:],
                                 order = (4, 2, 3),              # (p, d, q)
                                 seasonal_order = (P, D, Q, 12)) # (P, D, Q, S)

                # Fit SARIMA model.
                model = sarima.fit()

                # Generate predictions based on test set.
                # Start at time period 130 and end at 179.
                preds1 = model.predict(start=130, end=179)                
                
                # Evaluate predictions.
                print(f'The MSE for (4, 2, 3)x({P},{D},{Q},12) is: {mean_squared_error(test_others_2nddiff, preds1.iloc[:-2])}')
             
                
                # Save for final report.
                if mse > mean_squared_error(test_others_2nddiff, preds1.iloc[:-2]):
                    mse = mean_squared_error(test_others_2nddiff, preds1.iloc[:-2])
                    final_P = P
                    final_D = D
                    final_Q = Q
                
            except:
                pass

print(f'Our model that minimizes MSE on the training data is the SARIMA(4, 2, 3)x({final_P},{final_D},{final_Q},12).')
print(f'This model has an MSE of {mse}.')
# Out:
# Our model that minimizes MSE on the training data is the SARIMA(4, 2, 3)x(0,0,0,12).
# This model has an MSE of 990000000000000000.

# %%
# Fit a SARIMA(4, 2, 3) x (2, 0, 1, 12) model.

sarima = SARIMAX(endog = train_others_2nddiff.iloc[2:],
                 order = (4, 2, 3),              # (p, d, q)
                 seasonal_order = (2, 0, 1, 12)) # (P, D, Q, S)

# Fit SARIMA model.
model = sarima.fit()

# Generate predictions based on test set.
# Start at time period 130 and end at 185.
preds1 = model.predict(start=130, end=185)

# Evaluate predictions.
mean_squared_error(test_others_2nddiff, preds1.iloc[:-1])
# Out:
# 0.010813279136732619

# %%
# Check the data format
train_others_2nddiff.iloc[2:].head()
# Out:
# month
# 2005-03    1.000000e-01
# 2005-04    1.110223e-16
# 2005-05   -1.000000e-01
# 2005-06    0.000000e+00
# 2005-07   -1.000000e-01
# Name: others_2nddiff, dtype: float64

# %%
# Check the data format
test_others_2nddiff.head()
# Out:
# month
# 2016-01    0.0
# 2016-02   -0.1
# 2016-03    0.1
# 2016-04    0.2
# 2016-05   -0.2
# Name: others_2nddiff, dtype: float64

# %%
# Check the data format
preds1.head()
# Out:
# 2016-01-01    0.006547
# 2016-02-01   -0.069408
# 2016-03-01    0.178990
# 2016-04-01    0.056841
# 2016-05-01   -0.170011
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# preds1 has days. need to remove it in-order to combine these with train/test to plot.

# %%
# changing datetime index into column for manipulation
preds1_clean = preds1.reset_index()
preds1_clean.head()
# Out:
#        index  predicted_mean
# 0 2016-01-01        0.006547
# 1 2016-02-01       -0.069408
# 2 2016-03-01        0.178990
# 3 2016-04-01        0.056841
# 4 2016-05-01       -0.170011

# %%
# applying lambda function to change format of "index" datetime column into (YYYY-MM)
preds1_clean["index"] = preds1_clean['index'].apply(lambda x:x.strftime('%Y-%m'))
preds1_clean.head()
# Out:
#      index  predicted_mean
# 0  2016-01        0.006547
# 1  2016-02       -0.069408
# 2  2016-03        0.178990
# 3  2016-04        0.056841
# 4  2016-05       -0.170011

# %%
# resetting the "index" from the datetime column
preds1_clean.set_index("index", inplace = True)
preds1_clean.head()
# Out:
#          predicted_mean
# index
# 2016-01        0.006547
# 2016-02       -0.069408
# 2016-03        0.178990
# 2016-04        0.056841
# 2016-05       -0.170011

# %%
# Plot data.
plt.figure(figsize=(30, 12))
plt.plot(train_others_2nddiff.iloc[2:], color = 'blue')
plt.plot(test_others_2nddiff, color = 'orange')
plt.plot(preds1_clean, color = 'green')
plt.title(label = 'Electricity Consumption for other housing type with SARIMA(4, 2, 3)x(2, 0, 1, 12) Predictions', fontsize=22)
plt.xticks(rotation=90, fontsize=6)
plt.show();

# %% [markdown]
# #### Interpretation:
#
# Our model gives a lesser variance of the electricity consumption of Private Apartments and Condo. Also, the model does not give a good prediction because of the recent surge in the electricity consumption. Other than that, i feel that it gives quite a good predicition of the actual result.

# %% [markdown]
# ## 11. Conclusion
# [top](#Contents)

# %% [markdown]
# As Singapore enters phase 3 of circuit-breaker, the pace of economic recovery is slow as many people still Work from Home and the Home-Based Learning.
#
# We foresee the rate of household electricity consumption of 2021 is higher than usual, and it is quite difficult to predict the actual household electricity consumption because of the usage pattern is different from past years.

# %% [markdown]
# ## 12. References
# [top](#Contents)

# %% [markdown]
# [1] Sunshine duration. https://en.wikipedia.org/wiki/Sunshine_duration
#
# [2] List of cities by sunshine duration https://en.wikipedia.org/wiki/List_of_cities_by_sunshine_duration
